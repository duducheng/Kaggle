# %%
# Data Analysis Specific
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Marchine Learning Specific
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split

% matplotlib inline

# %%
dtrain = pd.read_csv('data/train.csv')
dtest = pd.read_csv('data/test.csv')
dtrain.columns
# Out:
# Index([u'label', u'pixel0', u'pixel1', u'pixel2', u'pixel3', u'pixel4',
#        u'pixel5', u'pixel6', u'pixel7', u'pixel8',
#        ...
#        u'pixel774', u'pixel775', u'pixel776', u'pixel777', u'pixel778',
#        u'pixel779', u'pixel780', u'pixel781', u'pixel782', u'pixel783'],
#       dtype='object', length=785)

# %%
Xfull, yfull = dtrain.drop('label',axis =1), dtrain['label']
Xtrain, Xvalid, ytrain, yvalid = train_test_split(Xfull, yfull, test_size=0.1)

# %% [markdown]
# # Firstly, let's try Random Forest

# %%
rf = RandomForestClassifier(100)
rf.fit(Xtrain,ytrain)
print('Training score:',rf.score(Xtrain,ytrain))
print('Validation score:', rf.score(Xvalid,yvalid))
# Out:
# ('Training score:', 1.0)
# ('Validation score:', 0.96642857142857141)

# %% [markdown]
# Yes, we get a working model :)
#
# Let's train the Random Forest model on the full dataset

# %%
rf_full = RandomForestClassifier(100)
rf_full.fit(Xfull,yfull)
rf_result = rf_full.predict(dtest)

# %%
pd.DataFrame({'ImageId': range(1, len(rf_result)+1), 'Label':rf_result}).to_csv('result/rf.csv',index = None) # get 0.96314

# %% [markdown]
# # Then, we can work on TensorFlow

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

def reformat(dataset = None, label = None):
  pixel_depth = 255.0  
  if dataset is not None:
    dataset = (dataset.values.reshape((-1, image_size, image_size, num_channels)).astype(np.float32) - pixel_depth/2) / pixel_depth
  if label is not None:
    label = (np.arange(num_labels) == label.values[:,None]).astype(np.float32)
  return dataset, label

# %%
tensorXfull, tensoryfull = reformat(Xfull, yfull)
tensorXvalid, tensoryvalid = reformat(Xvalid, yvalid)
tensorXtrain, tensorytrain = reformat(Xtrain, ytrain)
tensordtest, _ = reformat(dtest)
print 'Full', tensorXfull.shape, tensoryfull.shape
print 'Training', tensorXtrain.shape, tensorytrain.shape
print 'Validation', tensorXvalid.shape, tensoryvalid.shape
print 'Testing', tensordtest.shape
# Out:
# Full (42000, 28, 28, 1) (42000, 10)
# Training (37800, 28, 28, 1) (37800, 10)
# Validation (4200, 28, 28, 1) (4200, 10)
# Testing (28000, 28, 28, 1)

# %%
def onehot2label(tensor_y):
    y = np.argmax(tensor_y, axis = 1)
    return y

# %%
def accuracy(predictions, labels):
  return ((100.0 * np.sum(onehot2label(predictions) == onehot2label(labels))))/ predictions.shape[0]

# %%
accuracy(tensoryvalid, reformat(label = yvalid)[1])
# Out:
# 100.0

# %%
def display(img):
    image_width,image_height, _ = img.shape
    # (28, 28, 1) -> (28, 28)
    image = img.reshape(image_width,image_height) 
    plt.axis('off')
    plt.imshow(image)

# output image 
show = 8888
display(tensorXfull[show])
print "A normalized image of", onehot2label(tensoryfull)[show]
# Out:
# A normalized image of 8

# %%
import tensorflow as tf

# %% [markdown]
# ## build the graph

# %%
batch_size = 16
patch_size = 5
conv1_depth = 16
conv2_depth = 2*16
full_num1 = 192
full_num2 = 64
patch_stride = 1
pool_size = 2
pool_stride = 2
keep_conv = 0.8
keep_hidden = 0.5

myConvnet = tf.Graph()

with myConvnet.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(tensorXvalid)
  tf_test_dataset0 = tf.constant(tensordtest[:10000])
  tf_test_dataset1 = tf.constant(tensordtest[10000:20000])
  tf_test_dataset2 = tf.constant(tensordtest[20000:])
  
  # Variables.
  ceil_divide = lambda x,y: x//y+(x%y!=0) 
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, conv1_depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([conv1_depth]))
  # size_ratio = (patch_stride) * (pool_stride)
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, conv1_depth, conv2_depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(0.0, shape=[conv2_depth]))
  size_ratio = (patch_stride**2) * (pool_stride**2)
  layer3_weights = tf.Variable(tf.truncated_normal(
      [ceil_divide(image_size, size_ratio) * ceil_divide(image_size, size_ratio) * conv2_depth, full_num1], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(0.0, shape=[full_num1]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [full_num1, full_num2], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(0.0, shape=[full_num2]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [full_num2, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(0.0, shape=[num_labels]))
    
  # Model.
  def model(data, dropout = False):
    conv1 = tf.nn.conv2d(data, layer1_weights, strides=[1, patch_stride, patch_stride, 1], padding='SAME')
    pooling1 = tf.nn.max_pool(conv1,ksize=[1, pool_size, pool_size, 1], strides=[1, pool_stride, pool_stride, 1], padding='SAME')
    hidden1 = tf.nn.relu6(pooling1 + layer1_biases)
    if dropout:
        hidden1 = tf.nn.dropout(hidden1, keep_prob = keep_conv)
    conv2 = tf.nn.conv2d(hidden1, layer2_weights, strides=[1, patch_stride, patch_stride, 1], padding='SAME')
    pooling2 = tf.nn.max_pool(conv2,ksize=[1, pool_size, pool_size, 1], strides=[1, pool_stride, pool_stride, 1], padding='SAME')
    hidden2 = tf.nn.relu6(pooling2 + layer2_biases)
    if dropout:
        hidden2 = tf.nn.dropout(hidden2, keep_prob = keep_conv)
    shape = hidden2.get_shape().as_list()
    reshape = tf.reshape(hidden2, [shape[0], shape[1] * shape[2] * shape[3]])
    full_hidden1 = tf.nn.relu6(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if dropout:
        full_hidden1 = tf.nn.dropout(full_hidden1, keep_prob = keep_hidden)
    full_hidden2 = tf.nn.relu6(tf.matmul(full_hidden1, layer4_weights) + layer4_biases)
    if dropout:
        full_hidden2 = tf.nn.dropout(full_hidden2, keep_prob = keep_hidden) 
        
    return tf.matmul(full_hidden2, layer5_weights) + layer5_biases

  # Training computation.
  logits = model(tf_train_dataset, dropout = True)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(0.033).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction0 = tf.nn.softmax(model(tf_test_dataset0))
  test_prediction1 = tf.nn.softmax(model(tf_test_dataset1))
  test_prediction2 = tf.nn.softmax(model(tf_test_dataset2))

# %% [markdown]
# ## training
# Make test data into 3 partials to avoid memory problem.

# %%
keep_step = 0
checkpoints = [0,500,1000]

init = False
if checkpoints[0] == 0:
    init = True
    checkpoints = checkpoints[1:]
    
for checkpoint in checkpoints:
    with tf.Session(graph=myConvnet) as session:
        if init:
            tf.initialize_all_variables().run()
            print('Initialized')
            init = False
        else:
            saver.restore(session, "save/myConvnet_%s"%(keep_step))
            print("myConvnet_%s restored"%(keep_step))
        saver = tf.train.Saver()
        for step in range(keep_step, checkpoint):
            offset = (step * batch_size) % (tensorytrain.shape[0] - batch_size)
            batch_data = tensorXtrain[offset:(offset + batch_size), :, :, :]
            batch_labels = tensorytrain[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 50 == 0 or step == checkpoint-1):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), tensoryvalid))#虽然eval会再跑一次图，但跑的时候并没有feed_dict
        keep_step = checkpoint
        test_submission0 = onehot2label(test_prediction0.eval())
        test_submission1 = onehot2label(test_prediction1.eval())
        test_submission2 = onehot2label(test_prediction2.eval())
        test_submission = np.concatenate([test_submission0,test_submission1,test_submission2])
        pd.DataFrame({'ImageId': range(1, len(test_submission)+1), 'Label':test_submission}).to_csv(
            'result/myConvnet_%s.csv' % keep_step,index = None)
        save_path = saver.save(session, "save/myConvnet_%s"%(keep_step))
        print("Model saved in file: %s\n" % save_path)

print('Finished, made checkpoints %s, keep_step=%s'%(checkpoints,keep_step))
# Out:
# Initialized
# Minibatch loss at step 0: 2.427281
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.3%
# Minibatch loss at step 50: 2.118267
# Minibatch accuracy: 31.2%
# Validation accuracy: 25.0%
# Minibatch loss at step 100: 1.416213
# Minibatch accuracy: 56.2%
# Validation accuracy: 54.9%
# Minibatch loss at step 150: 0.994207
# Minibatch accuracy: 56.2%
# Validation accuracy: 76.7%
# Minibatch loss at step 200: 1.154144
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 250: 0.563576
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 300: 0.815534
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.9%
# Minibatch loss at step 350: 0.931083
# Minibatch accuracy: 75.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 400: 0.890500
# Minibatch accuracy: 68.8%
# Validation accuracy: 93.7%
# Minibatch loss at step 450: 0.397159
# Minibatch accuracy: 81.2%
# Validation accuracy: 93.7%
# Minibatch loss at step 499: 0.568483
# Minibatch accuracy: 81.2%
# Validation accuracy: 94.8%
# Model saved in file: save/myConvnet_500
#
# myConvnet_500 restored
# Minibatch loss at step 500: 0.718684
# Minibatch accuracy: 81.2%
# Validation accuracy: 94.4%
# Minibatch loss at step 550: 0.743071
# Minibatch accuracy: 68.8%
# Validation accuracy: 94.6%
# Minibatch loss at step 600: 0.193697
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.2%
# Minibatch loss at step 650: 0.302657
# Minibatch accuracy: 87.5%
# Validation accuracy: 94.8%
# Minibatch loss at step 700: 0.626423
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.0%
# Minibatch loss at step 750: 0.301335
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.2%
# Minibatch loss at step 800: 0.400833
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.8%
# Minibatch loss at step 850: 0.212807
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.9%
# Minibatch loss at step 900: 0.627999
# Minibatch accuracy: 81.2%
# Validation accuracy: 95.5%
# Minibatch loss at step 950: 0.438813
# Minibatch accuracy: 87.5%
# Validation accuracy: 96.3%
# Minibatch loss at step 999: 0.837721
# Minibatch accuracy: 87.5%
# Validation accuracy: 96.2%
# Model saved in file: save/myConvnet_1000
#
# Finished, made checkpoints [500, 1000], keep_step=1000

# %% [markdown]
# Ok, again, we got a working model (0.96371). Change the feed data source from Xtrain,ytrain into Xfull,ytrain, while to keep it brief, I will keep the Xvalid and yvalid.
#
# However, we can find, even for this case, valid dataset cannot get too high accuracy when step is not too much.

# %%
keep_step = 0
checkpoints = [0,800,1600,2400,3000]

init = False
if checkpoints[0] == 0:
    init = True
    checkpoints = checkpoints[1:]
    
for checkpoint in checkpoints:
    with tf.Session(graph=myConvnet) as session:
        if init:
            tf.initialize_all_variables().run()
            print('Initialized')
            init = False
        else:
            saver.restore(session, "save/myConvnet_%s"%(keep_step))
            print("myConvnet_%s restored"%(keep_step))
        saver = tf.train.Saver()
        for step in range(keep_step, checkpoint):
            offset = (step * batch_size) % (tensoryfull.shape[0] - batch_size)
            batch_data = tensorXfull[offset:(offset + batch_size), :, :, :]
            batch_labels = tensoryfull[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 50 == 0 or step == checkpoint-1):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), tensoryvalid))#虽然eval会再跑一次图，但跑的时候并没有feed_dict
        keep_step = checkpoint
        test_submission0 = onehot2label(test_prediction0.eval())
        test_submission1 = onehot2label(test_prediction1.eval())
        test_submission2 = onehot2label(test_prediction2.eval())
        test_submission = np.concatenate([test_submission0,test_submission1,test_submission2])
        pd.DataFrame({'ImageId': range(1, len(test_submission)+1), 'Label':test_submission}).to_csv(
            'result/myConvnet_%s.csv' % keep_step,index = None)
        save_path = saver.save(session, "save/myConvnet_%s"%(keep_step))
        print("Model saved in file: %s\n" % save_path)

print('Finished, made checkpoints %s, keep_step=%s'%(checkpoints,keep_step))
# Out:
# Initialized
# Minibatch loss at step 0: 2.628372
# Minibatch accuracy: 6.2%
# Validation accuracy: 11.1%
# Minibatch loss at step 50: 2.189080
# Minibatch accuracy: 25.0%
# Validation accuracy: 38.7%
# Minibatch loss at step 100: 1.557027
# Minibatch accuracy: 31.2%
# Validation accuracy: 65.3%
# Minibatch loss at step 150: 1.182891
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 200: 1.099656
# Minibatch accuracy: 56.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 250: 0.642806
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 300: 0.864909
# Minibatch accuracy: 56.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 350: 0.706061
# Minibatch accuracy: 62.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 400: 0.618312
# Minibatch accuracy: 75.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 450: 0.280300
# Minibatch accuracy: 87.5%
# Validation accuracy: 93.3%
# Minibatch loss at step 500: 0.277637
# Minibatch accuracy: 93.8%
# Validation accuracy: 94.5%
# Minibatch loss at step 550: 0.449229
# Minibatch accuracy: 87.5%
# Validation accuracy: 94.1%
# Minibatch loss at step 600: 0.556700
# Minibatch accuracy: 81.2%
# Validation accuracy: 95.1%
# Minibatch loss at step 650: 0.292466
# Minibatch accuracy: 93.8%
# Validation accuracy: 94.5%
# Minibatch loss at step 700: 0.109795
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.1%
# Minibatch loss at step 750: 0.211903
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.0%
# Minibatch loss at step 799: 0.365763
# Minibatch accuracy: 87.5%
# Validation accuracy: 94.9%
# Model saved in file: save/myConvnet_800
#
# myConvnet_800 restored
# Minibatch loss at step 800: 0.260367
# Minibatch accuracy: 87.5%
# Validation accuracy: 94.8%
# Minibatch loss at step 850: 0.911237
# Minibatch accuracy: 87.5%
# Validation accuracy: 95.8%
# Minibatch loss at step 900: 0.581198
# Minibatch accuracy: 87.5%
# Validation accuracy: 95.5%
# Minibatch loss at step 950: 0.126887
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.9%
# Minibatch loss at step 1000: 0.635140
# Minibatch accuracy: 87.5%
# Validation accuracy: 96.0%
# Minibatch loss at step 1050: 0.920632
# Minibatch accuracy: 81.2%
# Validation accuracy: 96.2%
# Minibatch loss at step 1100: 0.365876
# Minibatch accuracy: 87.5%
# Validation accuracy: 96.1%
# Minibatch loss at step 1150: 0.119617
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 1200: 0.373170
# Minibatch accuracy: 87.5%
# Validation accuracy: 96.0%
# Minibatch loss at step 1250: 0.194072
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.4%
# Minibatch loss at step 1300: 0.591935
# Minibatch accuracy: 75.0%
# Validation accuracy: 96.5%
# Minibatch loss at step 1350: 0.632676
# Minibatch accuracy: 87.5%
# Validation accuracy: 96.5%
# Minibatch loss at step 1400: 0.263949
# Minibatch accuracy: 87.5%
# Validation accuracy: 96.6%
# Minibatch loss at step 1450: 0.456927
# Minibatch accuracy: 87.5%
# Validation accuracy: 96.9%
# Minibatch loss at step 1500: 0.047286
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.8%
# Minibatch loss at step 1550: 0.228150
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.4%
# Minibatch loss at step 1599: 0.104343
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.1%
# Model saved in file: save/myConvnet_1600
#
# myConvnet_1600 restored
# Minibatch loss at step 1600: 0.611566
# Minibatch accuracy: 81.2%
# Validation accuracy: 97.0%
# Minibatch loss at step 1650: 0.227277
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.0%
# Minibatch loss at step 1700: 0.494420
# Minibatch accuracy: 87.5%
# Validation accuracy: 97.0%
# Minibatch loss at step 1750: 1.750786
# Minibatch accuracy: 81.2%
# Validation accuracy: 96.9%
# Minibatch loss at step 1800: 0.027420
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.1%
# Minibatch loss at step 1850: 0.065196
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.2%
# Minibatch loss at step 1900: 0.138012
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.1%
# Minibatch loss at step 1950: 0.115559
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.2%
# Minibatch loss at step 2000: 0.022464
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.1%
# Minibatch loss at step 2050: 0.256338
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.2%
# Minibatch loss at step 2100: 0.100461
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.2%
# Minibatch loss at step 2150: 0.243149
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.0%
# Minibatch loss at step 2200: 0.073064
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.0%
# Minibatch loss at step 2250: 0.094285
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.4%
# Minibatch loss at step 2300: 0.179918
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.4%
# Minibatch loss at step 2350: 0.235091
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.4%
# Minibatch loss at step 2399: 0.307083
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.3%
# Model saved in file: save/myConvnet_2400
#
# myConvnet_2400 restored
# Minibatch loss at step 2400: 0.006782
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 2450: 0.066079
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.5%
# Minibatch loss at step 2500: 0.467202
# Minibatch accuracy: 81.2%
# Validation accuracy: 97.5%
# Minibatch loss at step 2550: 0.074653
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 2600: 0.131302
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.4%
# Minibatch loss at step 2650: 0.064619
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.5%
# Minibatch loss at step 2700: 0.065722
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.5%
# Minibatch loss at step 2750: 0.143546
# Minibatch accuracy: 87.5%
# Validation accuracy: 97.4%
# Minibatch loss at step 2800: 0.232064
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.4%
# Minibatch loss at step 2850: 0.293491
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.5%
# Minibatch loss at step 2900: 0.039421
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 2950: 0.646745
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.4%
# Minibatch loss at step 2999: 0.019708
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.5%
# Model saved in file: save/myConvnet_3000
#
# Finished, made checkpoints [800, 1600, 2400, 3000], keep_step=3000

# %% [markdown]
# ### The model at step 3000 gets an accuracy of 0.97357, which is very closed to our valid accuray
# Continue to train the model into 7000 steps.

# %%
# keep_step = 3000
checkpoints = [5000, 7000]

init = False
if checkpoints[0] == 0:
    init = True
    checkpoints = checkpoints[1:]
    
for checkpoint in checkpoints:
    with tf.Session(graph=myConvnet) as session:
        if init:
            tf.initialize_all_variables().run()
            print('Initialized')
            init = False
        else:
            saver.restore(session, "save/myConvnet_%s"%(keep_step))
            print("myConvnet_%s restored"%(keep_step))
        saver = tf.train.Saver()
        for step in range(keep_step, checkpoint):
            offset = (step * batch_size) % (tensoryfull.shape[0] - batch_size)
            batch_data = tensorXfull[offset:(offset + batch_size), :, :, :]
            batch_labels = tensoryfull[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 50 == 0 or step == checkpoint-1):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), tensoryvalid))#虽然eval会再跑一次图，但跑的时候并没有feed_dict
        keep_step = checkpoint
        test_submission0 = onehot2label(test_prediction0.eval())
        test_submission1 = onehot2label(test_prediction1.eval())
        test_submission2 = onehot2label(test_prediction2.eval())
        test_submission = np.concatenate([test_submission0,test_submission1,test_submission2])
        pd.DataFrame({'ImageId': range(1, len(test_submission)+1), 'Label':test_submission}).to_csv(
            'result/myConvnet_%s.csv' % keep_step,index = None)
        save_path = saver.save(session, "save/myConvnet_%s"%(keep_step))
        print("Model saved in file: %s\n" % save_path)

print('Finished, made checkpoints %s, keep_step=%s'%(checkpoints,keep_step))
# Out:
# myConvnet_3000 restored
# Minibatch loss at step 3000: 0.017007
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.6%
# Minibatch loss at step 3050: 0.215833
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.6%
# Minibatch loss at step 3100: 0.055111
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.6%
# Minibatch loss at step 3150: 0.023573
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.5%
# Minibatch loss at step 3200: 0.048289
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.4%
# Minibatch loss at step 3250: 0.118741
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.8%
# Minibatch loss at step 3300: 0.069241
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.8%
# Minibatch loss at step 3350: 0.178685
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.9%
# Minibatch loss at step 3400: 0.230681
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.7%
# Minibatch loss at step 3450: 0.340008
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.6%
# Minibatch loss at step 3500: 0.204921
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.6%
# Minibatch loss at step 3550: 0.007838
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 3600: 0.003618
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.6%
# Minibatch loss at step 3650: 0.038390
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.9%
# Minibatch loss at step 3700: 0.060972
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 3750: 0.014725
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 3800: 0.042424
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.9%
# Minibatch loss at step 3850: 0.011577
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 3900: 0.037651
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 3950: 0.123446
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.6%
# Minibatch loss at step 4000: 0.221908
# Minibatch accuracy: 87.5%
# Validation accuracy: 97.7%
# Minibatch loss at step 4050: 0.037470
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.7%
# Minibatch loss at step 4100: 0.020415
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 4150: 0.222471
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.9%
# Minibatch loss at step 4200: 0.090360
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.8%
# Minibatch loss at step 4250: 0.040883
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.0%
# Minibatch loss at step 4300: 0.023652
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.6%
# Minibatch loss at step 4350: 0.009919
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.0%
# Minibatch loss at step 4400: 0.086034
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.9%
# Minibatch loss at step 4450: 0.209495
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.8%
# Minibatch loss at step 4500: 0.784431
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.9%
# Minibatch loss at step 4550: 0.099644
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.0%
# Minibatch loss at step 4600: 0.190418
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.0%
# Minibatch loss at step 4650: 0.008072
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.0%
# Minibatch loss at step 4700: 0.122212
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.2%
# Minibatch loss at step 4750: 0.088368
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.1%
# Minibatch loss at step 4800: 0.202075
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.0%
# Minibatch loss at step 4850: 0.536925
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.1%
# Minibatch loss at step 4900: 0.018779
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.0%
# Minibatch loss at step 4950: 0.075089
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.1%
# Minibatch loss at step 4999: 0.233250
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.1%
# Model saved in file: save/myConvnet_5000
#
# myConvnet_5000 restored
# Minibatch loss at step 5000: 0.053143
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.2%
# Minibatch loss at step 5050: 0.680384
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.1%
# Minibatch loss at step 5100: 0.165878
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.2%
# Minibatch loss at step 5150: 0.016848
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.2%
# Minibatch loss at step 5200: 0.145743
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.3%
# Minibatch loss at step 5250: 0.381667
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.3%
# Minibatch loss at step 5300: 0.089894
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.2%
# Minibatch loss at step 5350: 0.133010
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.3%
# Minibatch loss at step 5400: 0.033260
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.2%
# Minibatch loss at step 5450: 0.414741
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.2%
# Minibatch loss at step 5500: 0.323488
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.3%
# Minibatch loss at step 5550: 0.118547
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.2%
# Minibatch loss at step 5600: 0.018727
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 5650: 0.539583
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.3%
# Minibatch loss at step 5700: 0.192039
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.3%
# Minibatch loss at step 5750: 0.103200
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 5800: 0.187916
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.3%
# Minibatch loss at step 5850: 0.010993
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.2%
# Minibatch loss at step 5900: 0.013671
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 5950: 0.019600
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 6000: 0.003740
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 6050: 0.011439
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 6100: 0.190328
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.2%
# Minibatch loss at step 6150: 0.466568
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.3%
# Minibatch loss at step 6200: 0.070818
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Minibatch loss at step 6250: 0.025069
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 6300: 0.004982
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Minibatch loss at step 6350: 0.030339
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Minibatch loss at step 6400: 0.263709
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.4%
# Minibatch loss at step 6450: 0.032020
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 6500: 0.067090
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.4%
# Minibatch loss at step 6550: 0.116186
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.2%
# Minibatch loss at step 6600: 0.001834
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.2%
# Minibatch loss at step 6650: 0.061885
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Minibatch loss at step 6700: 0.182068
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.3%
# Minibatch loss at step 6750: 0.099262
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 6800: 0.095668
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 6850: 0.112859
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.5%
# Minibatch loss at step 6900: 0.031704
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 6950: 0.027303
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 6999: 0.014278
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Model saved in file: save/myConvnet_7000
#
# Finished, made checkpoints [5000, 7000], keep_step=7000

# %% [markdown]
# ### step 7000: 0.98471

# %%
# keep_step = 7000
checkpoints = [http://localhost:8888/notebooks/MNIST.ipynb#step-7000:-0.984718000]

init = False
if checkpoints[0] == 0:
    init = True
    checkpoints = checkpoints[1:]
    
for checkpoint in checkpoints:
    with tf.Session(graph=myConvnet) as session:
        if init:
            tf.initialize_all_variables().run()
            print('Initialized')
            init = False
        else:
            saver.restore(session, "save/myConvnet_%s"%(keep_step))
            print("myConvnet_%s restored"%(keep_step))
        saver = tf.train.Saver()
        for step in range(keep_step, checkpoint):
            offset = (step * batch_size) % (tensoryfull.shape[0] - batch_size)
            batch_data = tensorXfull[offset:(offset + batch_size), :, :, :]
            batch_labels = tensoryfull[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 50 == 0 or step == checkpoint-1):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), tensoryvalid))#虽然eval会再跑一次图，但跑的时候并没有feed_dict
        keep_step = checkpoint
        test_submission0 = onehot2label(test_prediction0.eval())
        test_submission1 = onehot2label(test_prediction1.eval())
        test_submission2 = onehot2label(test_prediction2.eval())
        test_submission = np.concatenate([test_submission0,test_submission1,test_submission2])
        pd.DataFrame({'ImageId': range(1, len(test_submission)+1), 'Label':test_submission}).to_csv(
            'result/myConvnet_%s.csv' % keep_step,index = None)
        save_path = saver.save(session, "save/myConvnet_%s"%(keep_step))
        print("Model saved in file: %s\n" % save_path)

print('Finished, made checkpoints %s, keep_step=%s'%(checkpoints,keep_step))
# Out:
# myConvnet_7000 restored
# Minibatch loss at step 7000: 0.086637
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 7050: 0.024162
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Minibatch loss at step 7100: 0.009842
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.3%
# Minibatch loss at step 7150: 0.021412
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Minibatch loss at step 7200: 0.027806
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 7250: 0.075942
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.5%
# Minibatch loss at step 7300: 0.072091
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.5%
# Minibatch loss at step 7350: 0.023652
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Minibatch loss at step 7400: 0.069789
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 7450: 0.011135
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 7500: 0.359770
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.5%
# Minibatch loss at step 7550: 0.255822
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.5%
# Minibatch loss at step 7600: 0.074676
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 7650: 0.032802
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 7700: 0.099491
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 7750: 0.119390
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.4%
# Minibatch loss at step 7800: 0.052428
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 7850: 0.556561
# Minibatch accuracy: 75.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 7900: 0.097590
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 7950: 0.022150
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 7999: 0.171880
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.6%
# Model saved in file: save/myConvnet_8000
#
# Finished, made checkpoints [8000], keep_step=8000

# %%
# keep_step = 8000
checkpoints = [9000, 10000]

init = False
if checkpoints[0] == 0:
    init = True
    checkpoints = checkpoints[1:]
    
for checkpoint in checkpoints:
    with tf.Session(graph=myConvnet) as session:
        if init:
            tf.initialize_all_variables().run()
            print('Initialized')
            init = False
        else:
            saver.restore(session, "save/myConvnet_%s"%(keep_step))
            print("myConvnet_%s restored"%(keep_step))
        saver = tf.train.Saver()
        for step in range(keep_step, checkpoint):
            offset = (step * batch_size) % (tensoryfull.shape[0] - batch_size)
            batch_data = tensorXfull[offset:(offset + batch_size), :, :, :]
            batch_labels = tensoryfull[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 100 == 0 or step == checkpoint-1):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), tensoryvalid))#虽然eval会再跑一次图，但跑的时候并没有feed_dict
        keep_step = checkpoint
        test_submission0 = onehot2label(test_prediction0.eval())
        test_submission1 = onehot2label(test_prediction1.eval())
        test_submission2 = onehot2label(test_prediction2.eval())
        test_submission = np.concatenate([test_submission0,test_submission1,test_submission2])
        pd.DataFrame({'ImageId': range(1, len(test_submission)+1), 'Label':test_submission}).to_csv(
            'result/myConvnet_%s.csv' % keep_step,index = None)
        save_path = saver.save(session, "save/myConvnet_%s"%(keep_step))
        print("Model saved in file: %s\n" % save_path)

print('Finished, made checkpoints %s, keep_step=%s'%(checkpoints,keep_step))
# Out:
# myConvnet_8000 restored
# Minibatch loss at step 8000: 0.031022
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 8100: 0.006493
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.4%
# Minibatch loss at step 8200: 0.011241
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 8300: 0.372169
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.6%
# Minibatch loss at step 8400: 0.000638
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 8500: 0.008280
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 8600: 0.020270
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 8700: 0.072936
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 8800: 0.016616
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 8900: 0.007648
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 8999: 0.000457
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Model saved in file: save/myConvnet_9000
#
# myConvnet_9000 restored
# Minibatch loss at step 9000: 0.144388
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.7%
# Minibatch loss at step 9100: 0.303998
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.7%
# Minibatch loss at step 9200: 0.049508
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 9300: 0.049371
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 9400: 0.071366
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 9500: 0.007261
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 9600: 0.071253
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 9700: 0.317346
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.7%
# Minibatch loss at step 9800: 0.606022
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.6%
# Minibatch loss at step 9900: 0.011741
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 9999: 0.067836
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Model saved in file: save/myConvnet_10000
#
# Finished, made checkpoints [9000, 10000], keep_step=10000

# %%
# keep_step = 10000
checkpoints = [12000, 14000,16000]

init = False
if checkpoints[0] == 0:
    init = True
    checkpoints = checkpoints[1:]
    
for checkpoint in checkpoints:
    with tf.Session(graph=myConvnet) as session:
        if init:
            tf.initialize_all_variables().run()
            print('Initialized')
            init = False
        else:
            saver.restore(session, "save/myConvnet_%s"%(keep_step))
            print("myConvnet_%s restored"%(keep_step))
        saver = tf.train.Saver()
        for step in range(keep_step, checkpoint):
            offset = (step * batch_size) % (tensoryfull.shape[0] - batch_size)
            batch_data = tensorXfull[offset:(offset + batch_size), :, :, :]
            batch_labels = tensoryfull[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 100 == 0 or step == checkpoint-1):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), tensoryvalid))#虽然eval会再跑一次图，但跑的时候并没有feed_dict
        keep_step = checkpoint
        test_submission0 = onehot2label(test_prediction0.eval())
        test_submission1 = onehot2label(test_prediction1.eval())
        test_submission2 = onehot2label(test_prediction2.eval())
        test_submission = np.concatenate([test_submission0,test_submission1,test_submission2])
        pd.DataFrame({'ImageId': range(1, len(test_submission)+1), 'Label':test_submission}).to_csv(
            'result/myConvnet_%s.csv' % keep_step,index = None)
        save_path = saver.save(session, "save/myConvnet_%s"%(keep_step))
        print("Model saved in file: %s\n" % save_path)

print('Finished, made checkpoints %s, keep_step=%s'%(checkpoints,keep_step))
# Out:
# myConvnet_10000 restored
# Minibatch loss at step 10000: 0.030690
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 10100: 0.030761
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 10200: 0.097138
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.8%
# Minibatch loss at step 10300: 0.160224
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.8%
# Minibatch loss at step 10400: 0.031392
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 10500: 0.311960
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.8%
# Minibatch loss at step 10600: 0.031685
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Minibatch loss at step 10700: 0.476586
# Minibatch accuracy: 87.5%
# Validation accuracy: 98.8%
# Minibatch loss at step 10800: 0.011149
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 10900: 0.107135
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 11000: 0.007175
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 11100: 0.060754
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Minibatch loss at step 11200: 0.250853
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.7%
# Minibatch loss at step 11300: 0.004608
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 11400: 0.033406
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 11500: 0.130168
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.8%
# Minibatch loss at step 11600: 0.145617
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.8%
# Minibatch loss at step 11700: 0.008883
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Minibatch loss at step 11800: 0.003983
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 11900: 0.048918
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Minibatch loss at step 11999: 0.028641
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Model saved in file: save/myConvnet_12000
#
# myConvnet_12000 restored
# Minibatch loss at step 12000: 0.042467
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Minibatch loss at step 12100: 0.046863
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 12200: 0.014825
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 12300: 0.162013
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.9%
# Minibatch loss at step 12400: 0.010991
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 12500: 0.004836
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 12600: 0.172977
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.9%
# Minibatch loss at step 12700: 0.021568
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Minibatch loss at step 12800: 0.256613
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.0%
# Minibatch loss at step 12900: 0.010416
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Minibatch loss at step 13000: 0.007056
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 13100: 0.044444
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 13200: 0.028699
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.8%
# Minibatch loss at step 13300: 0.355865
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.8%
# Minibatch loss at step 13400: 0.119740
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.8%
# Minibatch loss at step 13500: 0.075094
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.9%
# Minibatch loss at step 13600: 0.083655
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.7%
# Minibatch loss at step 13700: 0.045026
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 13800: 0.301459
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.0%
# Minibatch loss at step 13900: 0.009218
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 13999: 0.022613
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Model saved in file: save/myConvnet_14000
#
# myConvnet_14000 restored
# Minibatch loss at step 14000: 0.017296
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 14100: 0.030036
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 14200: 0.009372
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.9%
# Minibatch loss at step 14300: 0.053695
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 14400: 0.002764
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 14500: 0.216150
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.0%
# Minibatch loss at step 14600: 0.255271
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.0%
# Minibatch loss at step 14700: 0.172828
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.0%
# Minibatch loss at step 14800: 0.050602
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.0%
# Minibatch loss at step 14900: 0.006913
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 15000: 0.034095
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 15100: 0.004709
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 15200: 0.008915
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 15300: 0.075061
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.1%
# Minibatch loss at step 15400: 0.006678
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 15500: 0.019410
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 15600: 0.036810
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 15700: 0.167936
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.1%
# Minibatch loss at step 15800: 0.194244
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.9%
# Minibatch loss at step 15900: 0.004947
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 15999: 0.102614
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.0%
# Model saved in file: save/myConvnet_16000
#
# Finished, made checkpoints [12000, 14000, 16000], keep_step=16000

# %%
# keep_step = 16000
checkpoints = [18000, 21000,24000]

init = False
if checkpoints[0] == 0:
    init = True
    checkpoints = checkpoints[1:]
    
for checkpoint in checkpoints:
    with tf.Session(graph=myConvnet) as session:
        if init:
            tf.initialize_all_variables().run()
            print('Initialized')
            init = False
        else:
            saver.restore(session, "save/myConvnet_%s"%(keep_step))
            print("myConvnet_%s restored"%(keep_step))
        saver = tf.train.Saver()
        for step in range(keep_step, checkpoint):
            offset = (step * batch_size) % (tensoryfull.shape[0] - batch_size)
            batch_data = tensorXfull[offset:(offset + batch_size), :, :, :]
            batch_labels = tensoryfull[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 100 == 0 or step == checkpoint-1):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), tensoryvalid))#虽然eval会再跑一次图，但跑的时候并没有feed_dict
        keep_step = checkpoint
        test_submission0 = onehot2label(test_prediction0.eval())
        test_submission1 = onehot2label(test_prediction1.eval())
        test_submission2 = onehot2label(test_prediction2.eval())
        test_submission = np.concatenate([test_submission0,test_submission1,test_submission2])
        pd.DataFrame({'ImageId': range(1, len(test_submission)+1), 'Label':test_submission}).to_csv(
            'result/myConvnet_%s.csv' % keep_step,index = None)
        save_path = saver.save(session, "save/myConvnet_%s"%(keep_step))
        print("Model saved in file: %s\n" % save_path)

print('Finished, made checkpoints %s, keep_step=%s'%(checkpoints,keep_step))
# Out:
# myConvnet_16000 restored
# Minibatch loss at step 16000: 0.030761
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 16100: 0.051738
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 16200: 0.008638
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 16300: 0.094824
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 16400: 0.053215
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 16500: 0.024493
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 16600: 0.009455
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 16700: 0.006776
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Minibatch loss at step 16800: 0.111782
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.1%
# Minibatch loss at step 16900: 0.054231
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 17000: 0.030694
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 17100: 0.022811
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 17200: 0.532496
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.1%
# Minibatch loss at step 17300: 0.159822
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.1%
# Minibatch loss at step 17400: 0.031205
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 17500: 0.005398
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 17600: 0.000952
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 17700: 0.022228
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 17800: 0.008284
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 17900: 0.022555
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 17999: 0.042056
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.0%
# Model saved in file: save/myConvnet_18000
#
# myConvnet_18000 restored
# Minibatch loss at step 18000: 0.490709
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.0%
# Minibatch loss at step 18100: 0.117703
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.0%
# Minibatch loss at step 18200: 0.211276
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.1%
# Minibatch loss at step 18300: 0.109611
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 18400: 0.080146
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.1%
# Minibatch loss at step 18500: 0.024723
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 18600: 0.817046
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.3%
# Minibatch loss at step 18700: 0.036761
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 18800: 0.144434
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.3%
# Minibatch loss at step 18900: 0.015045
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 19000: 0.014245
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 19100: 0.122603
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.1%
# Minibatch loss at step 19200: 0.003577
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 19300: 0.146169
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.2%
# Minibatch loss at step 19400: 0.000819
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 19500: 0.012823
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 19600: 0.026035
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 19700: 0.017323
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 19800: 0.001431
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 19900: 0.022921
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 20000: 0.117467
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.2%
# Minibatch loss at step 20100: 0.082902
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 20200: 0.078651
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.2%
# Minibatch loss at step 20300: 0.105240
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.2%
# Minibatch loss at step 20400: 0.048449
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 20500: 0.992345
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.3%
# Minibatch loss at step 20600: 0.076556
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 20700: 0.003327
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 20800: 0.181610
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.2%
# Minibatch loss at step 20900: 0.064720
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 20999: 0.144343
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.3%
# Model saved in file: save/myConvnet_21000
#
# myConvnet_21000 restored
# Minibatch loss at step 21000: 0.054995
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 21100: 0.005580
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.1%
# Minibatch loss at step 21200: 0.004145
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 21300: 0.000993
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 21400: 0.271729
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.2%
# Minibatch loss at step 21500: 0.027735
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 21600: 0.016404
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 21700: 0.814063
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.2%
# Minibatch loss at step 21800: 0.003680
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 21900: 0.031879
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 22000: 0.003247
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 22100: 0.054468
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 22200: 0.011200
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 22300: 0.005941
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 22400: 0.022343
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 22500: 0.156287
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.4%
# Minibatch loss at step 22600: 0.003051
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 22700: 0.163722
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.4%
# Minibatch loss at step 22800: 0.019009
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 22900: 0.005454
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 23000: 0.037428
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 23100: 0.053026
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 23200: 0.054926
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.4%
# Minibatch loss at step 23300: 0.013201
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 23400: 0.029946
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 23500: 0.039899
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 23600: 0.027042
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 23700: 0.155811
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.3%
# Minibatch loss at step 23800: 0.048655
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 23900: 0.002998
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 23999: 0.004193
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Model saved in file: save/myConvnet_24000
#
# Finished, made checkpoints [18000, 21000, 24000], keep_step=24000

# %%
# keep_step = 24000
checkpoints = [28000, 32000,36000]

init = False
if checkpoints[0] == 0:
    init = True
    checkpoints = checkpoints[1:]
    
for checkpoint in checkpoints:
    with tf.Session(graph=myConvnet) as session:
        if init:
            tf.initialize_all_variables().run()
            print('Initialized')
            init = False
        else:
            saver.restore(session, "save/myConvnet_%s"%(keep_step))
            print("myConvnet_%s restored"%(keep_step))
        saver = tf.train.Saver()
        for step in range(keep_step, checkpoint):
            offset = (step * batch_size) % (tensoryfull.shape[0] - batch_size)
            batch_data = tensorXfull[offset:(offset + batch_size), :, :, :]
            batch_labels = tensoryfull[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 100 == 0 or step == checkpoint-1):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), tensoryvalid))#虽然eval会再跑一次图，但跑的时候并没有feed_dict
        keep_step = checkpoint
        test_submission0 = onehot2label(test_prediction0.eval())
        test_submission1 = onehot2label(test_prediction1.eval())
        test_submission2 = onehot2label(test_prediction2.eval())
        test_submission = np.concatenate([test_submission0,test_submission1,test_submission2])
        pd.DataFrame({'ImageId': range(1, len(test_submission)+1), 'Label':test_submission}).to_csv(
            'result/myConvnet_%s.csv' % keep_step,index = None)
        save_path = saver.save(session, "save/myConvnet_%s"%(keep_step))
        print("Model saved in file: %s\n" % save_path)

print('Finished, made checkpoints %s, keep_step=%s'%(checkpoints,keep_step))
# Out:
# myConvnet_24000 restored
# Minibatch loss at step 24000: 0.045920
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 24100: 0.373256
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.4%
# Minibatch loss at step 24200: 0.005116
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 24300: 0.001518
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 24400: 0.005995
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 24500: 0.006715
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 24600: 0.011234
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 24700: 0.006900
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.2%
# Minibatch loss at step 24800: 0.002456
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 24900: 0.053032
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 25000: 0.003035
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 25100: 0.055169
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 25200: 0.026335
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 25300: 0.070602
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 25400: 0.022414
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 25500: 0.001254
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 25600: 0.031859
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 25700: 0.014403
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.3%
# Minibatch loss at step 25800: 0.006750
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 25900: 0.026022
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 26000: 0.062437
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 26100: 0.577903
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.4%
# Minibatch loss at step 26200: 0.115692
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.5%
# Minibatch loss at step 26300: 0.000583
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 26400: 0.079079
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.4%
# Minibatch loss at step 26500: 0.148664
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.4%
# Minibatch loss at step 26600: 0.033097
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 26700: 0.100574
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.5%
# Minibatch loss at step 26800: 0.009551
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 26900: 0.000515
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 27000: 0.335468
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.4%
# Minibatch loss at step 27100: 0.028264
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 27200: 0.024426
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 27300: 0.002322
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 27400: 0.096156
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.3%
# Minibatch loss at step 27500: 0.140033
# Minibatch accuracy: 87.5%
# Validation accuracy: 99.5%
# Minibatch loss at step 27600: 0.005493
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 27700: 0.040100
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 27800: 0.169120
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.5%
# Minibatch loss at step 27900: 0.004126
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 27999: 0.065485
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Model saved in file: save/myConvnet_28000
#
# myConvnet_28000 restored
# Minibatch loss at step 28000: 0.018641
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 28100: 0.001992
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 28200: 0.000467
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 28300: 0.018997
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 28400: 0.026296
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 28500: 0.009314
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 28600: 0.011152
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 28700: 0.035390
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 28800: 0.000500
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 28900: 0.012034
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 29000: 0.001969
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 29100: 0.018686
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 29200: 0.041528
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 29300: 0.078854
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.5%
# Minibatch loss at step 29400: 0.008721
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 29500: 0.001269
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 29600: 0.001719
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.4%
# Minibatch loss at step 29700: 0.002826
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.7%
# Minibatch loss at step 29800: 0.008550
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 29900: 0.008979
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 30000: 0.003085
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.7%
# Minibatch loss at step 30100: 0.002475
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 30200: 0.095735
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.5%
# Minibatch loss at step 30300: 0.000948
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 30400: 0.009848
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 30500: 0.265038
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.6%
# Minibatch loss at step 30600: 0.013030
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 30700: 0.030509
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 30800: 0.008198
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 30900: 0.004030
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 31000: 0.053256
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 31100: 0.008892
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.7%
# Minibatch loss at step 31200: 0.007472
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 31300: 0.007621
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 31400: 0.013235
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 31500: 0.026962
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 31600: 0.007369
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 31700: 0.003049
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 31800: 0.001829
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 31900: 0.015198
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 31999: 0.119734
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.7%
# Model saved in file: save/myConvnet_32000
#
# myConvnet_32000 restored
# Minibatch loss at step 32000: 0.050245
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.7%
# Minibatch loss at step 32100: 0.328294
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.7%
# Minibatch loss at step 32200: 0.028634
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 32300: 0.053380
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 32400: 0.047301
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 32500: 0.011174
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 32600: 0.001962
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 32700: 0.097220
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.5%
# Minibatch loss at step 32800: 0.059451
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 32900: 0.003578
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 33000: 0.033893
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 33100: 0.190360
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.6%
# Minibatch loss at step 33200: 0.004703
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.7%
# Minibatch loss at step 33300: 0.016810
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 33400: 0.009147
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 33500: 0.027531
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 33600: 0.011591
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.7%
# Minibatch loss at step 33700: 0.028035
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 33800: 0.003495
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 33900: 0.004613
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 34000: 0.008592
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 34100: 0.065313
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.5%
# Minibatch loss at step 34200: 0.015463
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 34300: 0.027332
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 34400: 0.001089
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 34500: 0.029256
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.5%
# Minibatch loss at step 34600: 0.012180
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 34700: 0.029011
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 34800: 0.024137
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 34900: 0.317886
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.6%
# Minibatch loss at step 35000: 0.008152
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 35100: 0.005826
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 35200: 0.063263
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 35300: 0.095396
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.6%
# Minibatch loss at step 35400: 0.540796
# Minibatch accuracy: 93.8%
# Validation accuracy: 99.6%
# Minibatch loss at step 35500: 0.038777
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 35600: 0.001273
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 35700: 0.006244
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Minibatch loss at step 35800: 0.003953
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.7%
# Minibatch loss at step 35900: 0.028796
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.7%
# Minibatch loss at step 35999: 0.009662
# Minibatch accuracy: 100.0%
# Validation accuracy: 99.6%
# Model saved in file: save/myConvnet_36000
#
# Finished, made checkpoints [28000, 32000, 36000], keep_step=36000

# %% [markdown]
# # Step accuracy conclusion:
# 1. 1000: 0.96371, Validation: 96.2%
# 2. 3000: 0.97357, Validation: 97.5%
# 3. 7000: 0.98471, Validation: 98.4%
# 4. 9000: 0.98486, Validation: 98.7%
# 5. 10000: 0.98543, Validation: 98.6%
# 6. 21000: 0.98857, Validation: 99.3%
# 7. 28000: 0.99143, Validation: 99.5%
# 8. 36000: 0.99057, Validation: 99.6%, which seems some overfitting even with dropout.
