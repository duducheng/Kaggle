# %% [markdown]
# # [Blight Fight Capstone Project](https://github.com/uwescience/datasci_course_materials/blob/master/capstone/blight/blightfight.md)
#
# Download the data from the project page, and save it into **MY_DATA_PATH**

# %%
MY_DATA_PATH = './data/'

# %%
# Basic import 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import time
# %matplotlib inline

# Machine Learning import 
from sklearn.naive_bayes import GaussianNB
from sklearn.kernel_ridge import KernelRidge
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.svm import SVR, SVC
from sklearn.neighbors import KNeighborsRegressor
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV

# %%
raw_violations = pd.read_csv(MY_DATA_PATH + 'detroit-blight-violations.csv', low_memory=False)
raw_violations.head()
# Out:
#    TicketID TicketNumber                  AgencyName  \
# 0     26288  05000001DAH  Department of Public Works
# 1     19800  05000025DAH  Department of Public Works
# 2     19804  05000026DAH  Department of Public Works
# 3     20208  05000027DAH  Department of Public Works
# 4     20211  05000028DAH  Department of Public Works
#
#                     ViolName  ViolationStreetNumber ViolationStreetName  \
# 0  Group, LLC, Grand Holding                   2566    GRAND BLVD
# 1        JACKSON, RAECHELLE                   19014    ASHTON
# 2          TALTON, CAROL ANN                  18735    STAHELIN
# 3          BONNER, DARRYL E.                  20125    MONICA
# 4         GREGORY, JAMES LEE                  17397    PRAIRIE
#
#   MailingStreetNumber   MailingStreetName MailingCity MailingState  \
# 0                 743  Beaubien, Ste. 201     Detroit           MI
# 1               20501              HEYDEN     DETROIT           MI
# ...

# %%
raw_violations.dtypes
# Out:
# TicketID                   int64
# TicketNumber              object
# AgencyName                object
# ViolName                  object
# ViolationStreetNumber      int64
# ViolationStreetName       object
# MailingStreetNumber       object
# MailingStreetName         object
# MailingCity               object
# MailingState              object
# MailingZipCode            object
# NonUsAddressCode          object
# Country                   object
# TicketIssuedDT            object
# TicketIssuedTime          object
# HearingDT                 object
# CourtTime                 object
# ViolationCode             object
# ViolDescription           object
# Disposition               object
# FineAmt                   object
# AdminFee                  object
# LateFee                   object
# StateFee                  object
# CleanUpCost               object
# JudgmentAmt               object
# PaymentStatus             object
# Void                     float64
# ...

# %%
for col in raw_violations.columns:
    print 'Columns: %s \t\t Totally: %s items' % (col, len(raw_violations[col].unique()))
    print raw_violations[col].unique() 
    print 
    print
# Out:
# Columns: TicketID 		 Totally: 301567 items
# [ 26288  19800  19804 ..., 339177 339178 339179]
#
#
# Columns: TicketNumber 		 Totally: 301567 items
# ['05000001DAH' '05000025DAH' '05000026DAH' ..., '15011494DAH' '15011495DAH'
#  '15011496DAH']
#
#
# Columns: AgencyName 		 Totally: 5 items
# ['Department of Public Works' 'Building and Safety Engineering Department'
#  'Detroit Police Department' 'Health Department' 'Neighborhood City Halls']
#
#
# Columns: ViolName 		 Totally: 152622 items
# ['Group, LLC, Grand Holding' 'JACKSON, RAECHELLE ' 'TALTON, CAROL ANN' ...,
#  'KHANOM, HANIFA ' 'LEWIS JR, QUINCY C' 'DILLARD, LAKRESHA ']
#
#
# Columns: ViolationStreetNumber 		 Totally: 19650 items
# [ 2566 19014 18735 ..., 21615 15113 19531]
#
#
# Columns: ViolationStreetName 		 Totally: 2771 items
# ['GRAND BLVD      ' 'ASHTON          ' 'STAHELIN        ' ..., 'KIPLING '
#  'MAJESTIC ' 'GRANDVIEW ']
#
#
# Columns: MailingStreetNumber 		 Totally: 25485 items
# ...
