# %%
import os
from dateutil.parser import parse as dateutil_parse
from six.moves import cPickle as pickle
import time
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler as skStandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.cross_validation import train_test_split,cross_val_score

PATH = '../season_1/'
CLEAN_PATH = PATH+'clean/'

from mylib import myStandardScaler,process_order,process_traffic,get_order_group,get_traffic_group,XY_order_traffic, prediction2submit, Search_Model, DISTRICTS

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
cluster_map = pd.read_csv(CLEAN_PATH+'cluster_map.csv',index_col=0)
poi = pd.read_csv(CLEAN_PATH+'poi.csv',index_col=0)
train_order_group = pd.read_pickle(CLEAN_PATH+'train_order_group.pickle')
test_order_group = pd.read_pickle(CLEAN_PATH+'test_order_group.pickle')
train_traffic_group = pd.read_pickle(CLEAN_PATH+'train_traffic_group.pickle')
test_traffic_group = pd.read_pickle(CLEAN_PATH+'test_traffic_group.pickle')
test_target = pd.read_csv(CLEAN_PATH+'test_target.csv',index_col=0,parse_dates=True)

# %%
train_slot = pd.Index(sorted(train_order_group.values()[0].index.unique()))
train_slot = pd.Index(filter(lambda x: x%1000 >4,train_slot))
test_slot = test_target['datetimeslot']

# %%
now = time.time()

train_XY_group = dict()
for district in DISTRICTS:
    train_XY_group[district] = XY_order_traffic(district,train_order_group,train_traffic_group,train_slot)
test_XY_group = dict()
for district in DISTRICTS:
    test_XY_group[district] = XY_order_traffic(district,test_order_group,test_traffic_group,test_slot)
for district in DISTRICTS:
    scaler = myStandardScaler()
    train_XY_group[district][0] = scaler.fit_transform(train_XY_group[district][0])
    test_XY_group[district][0] = scaler.transform(test_XY_group[district][0])
    
stop = time.time()
print 'Take %02d:%02d:%02d' % ((stop-now)/3600,(stop-now)/60,(stop-now)%60)
# Out:
# Take 00:00:18

# %%
all_now = time.time()

grid_params = {'kernel': ['rbf'],'alpha': np.random.rand(200) * 7,'gamma': np.random.random(200)*1.5}

# grid_params = {'n_estimators': [100] ,'max_depth': [1], 'max_features': ['log2', 'sqrt']}

search_models = {district: Search_Model(KernelRidge) for district in DISTRICTS}
test_prediction = dict()
for district, model in search_models.items()[::-1]:
    now = time.time()
    print 'Searching %s...'%district
    model.fit(grid_params,*train_XY_group[district])
    test_prediction[district] = model.predict(test_XY_group[district][0]) - test_XY_group[district][1].fillna(0)
    with open('kr/test_prediction_%s.pickle'%(district),'wb') as f:
        pickle.dump(test_prediction[district],f)
    stop = time.time()
    print 'Take %02d:%02d:%02d' % ((stop-now)/3600,(stop-now)/60,(stop-now)%60)
    
all_stop = time.time()
print 'Totally take %02d:%02d:%02d' % ((all_stop-all_now)/3600,(all_stop-all_now)/60,(all_stop-all_now)%60)
# Out:
# Searching 2350be163432e42270d2670cb3c02f80...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0046750113253070102, 'alpha': 6.4898186384060388}
# CV score: 0.228530204505
# Fit (R2) score: 0.199643611601
# The metrics: 0.219881651458
# Take 00:03:27
# Searching 4b7f6f4e2bf237b6cc58f57142bea5c0...
# Best Params: {'kernel': 'rbf', 'gamma': 0.015496821809899863, 'alpha': 4.2353895352542725}
# CV score: 0.206073223498
# Fit (R2) score: 0.241450380042
# The metrics: 0.185754832733
# Take 00:03:08
# Searching 82cc4851f9e4faa4e54309f8bb73fd7c...
# Best Params: {'kernel': 'rbf', 'gamma': 0.20309024448654373, 'alpha': 4.8980469838679825}
# CV score: 0.863047155546
# Fit (R2) score: 0.146501715126
# The metrics: 0.715919813065
# Take 00:03:32
# Searching 74ec84f1cf75cf89ae176c8c6ceec5ba...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0116464218641541, 'alpha': 6.7214869434938409}
# CV score: 0.176202011451
# Fit (R2) score: 0.219111276843
# The metrics: 0.163449434682
# Take 00:03:26
# Searching b05379ac3f9b7d99370d443cfd5dcc28...
# Best Params: {'kernel': 'rbf', 'gamma': 0.22411252402284976, 'alpha': 6.6622600176157789}
# CV score: 0.756056848278
# Fit (R2) score: 0.0736963361597
# The metrics: 0.659018254489
# Take 00:03:46
# Searching 2920ece99323b4c111d6f9affc7ea034...
# Best Params: {'kernel': 'rbf', 'gamma': 0.1376210275083472, 'alpha': 6.8361290211697181}
# CV score: 0.703851400292
# Fit (R2) score: 0.109797945156
# The metrics: 0.612433571561
# Take 00:03:51
# Searching 7f84bdfc2b6d4541e1f6c0a3349e0251...
# Best Params: {'kernel': 'rbf', 'gamma': 0.015496821809899863, 'alpha': 3.024907608145404}
# CV score: 0.132080985693
# Fit (R2) score: 0.291664791486
# The metrics: 0.113334485398
# Take 00:03:52
# Searching 52a4e8aaa12f70020e889aed8fd5ddbc...
# Best Params: {'kernel': 'rbf', 'gamma': 0.04159478925506005, 'alpha': 5.3191050619036915}
# CV score: 0.446226984248
# Fit (R2) score: 0.245605510713
# The metrics: 0.386261507079
# Take 00:04:09
# Searching 4f4041f7db0c7f69892d9b74c1a7efa1...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0116464218641541, 'alpha': 6.8886575215886134}
# CV score: 0.208374221534
# Fit (R2) score: 0.298347812805
# The metrics: 0.192757044285
# Take 00:04:01
# Searching b26a240205c852804ff8758628c0a86a...
# Best Params: {'kernel': 'rbf', 'gamma': 0.10190022719513747, 'alpha': 4.7095178332209819}
# CV score: 0.613524369615
# Fit (R2) score: 0.201526278799
# The metrics: 0.510459317245
# Take 00:03:42
# Searching fff4e8465d1e12621bc361276b6217cf...
# Best Params: {'kernel': 'rbf', 'gamma': 0.043838966954732272, 'alpha': 1.6897182913176754}
# CV score: 0.217262300482
# Fit (R2) score: 0.48905575665
# The metrics: 0.15304623242
# Take 00:04:05
# Searching f2c8c4bb99e6377d21de71275afd6cd2...
# Best Params: {'kernel': 'rbf', 'gamma': 0.064003279297905336, 'alpha': 2.217856260937924}
# CV score: 0.266863757191
# Fit (R2) score: 0.414755924055
# The metrics: 0.19475822981
# Take 00:04:04
# Searching c4ec24e0a58ebedaa1661e5c09e47bb5...
# Best Params: {'kernel': 'rbf', 'gamma': 0.04159478925506005, 'alpha': 0.31561765141893283}
# CV score: 0.228757376833
# Fit (R2) score: 0.747480543588
# The metrics: 0.0998743454916
# Take 00:03:32
# Searching d05052b4bda7662a084f235e880f50fa...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0046750113253070102, 'alpha': 4.2746730626295761}
# CV score: 0.260337440145
# Fit (R2) score: 0.304641790911
# The metrics: 0.245890974648
# Take 00:04:06
# Searching 91690261186ae5bee8f83808ea1e4a01...
# Best Params: {'kernel': 'rbf', 'gamma': 0.11912534013182191, 'alpha': 5.2896045210279583}
# CV score: 0.598452372937
# Fit (R2) score: 0.249569302491
# The metrics: 0.509689794064
# Take 00:03:52
# Searching 1afd7afbc81ecc1b13886a569d869e8a...
# Best Params: {'kernel': 'rbf', 'gamma': 0.14806279040207299, 'alpha': 5.7031198187231213}
# CV score: 0.715738893588
# Fit (R2) score: 0.171988797776
# The metrics: 0.612902924816
# Take 00:03:42
# Searching 58c7a4888306d8ff3a641d1c0feccbe3...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0046750113253070102, 'alpha': 0.74414793566226201}
# CV score: 0.175576873548
# Fit (R2) score: 0.320362394427
# The metrics: 0.152610246045
# Take 00:03:51
# Searching a735449c5c09df639c35a7d61fad3ee5...
# Best Params: {'kernel': 'rbf', 'gamma': 0.015496821809899863, 'alpha': 2.5376012105414638}
# CV score: 0.123964552949
# Fit (R2) score: 0.293195515217
# The metrics: 0.106825801926
# Take 00:03:57
# Searching d4ec2125aff74eded207d2d915ef682f...
# Best Params: {'kernel': 'rbf', 'gamma': 0.36407099095444118, 'alpha': 0.45387268909297374}
# CV score: 0.834381331961
# Fit (R2) score: 0.8861109918
# The metrics: 0.27147089997
# Take 00:04:13
# Searching fc34648599753c9e74ab238e9a4a07ad...
# Best Params: {'kernel': 'rbf', 'gamma': 0.064003279297905336, 'alpha': 2.6310488953983375}
# CV score: 0.697960242037
# Fit (R2) score: 0.246066243233
# The metrics: 0.521334966118
# Take 00:03:41
# Searching bf44d327f0232325c6d5280926d7b37d...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0116464218641541, 'alpha': 2.2176170828673216}
# CV score: 0.191951664537
# Fit (R2) score: 0.190776866315
# The metrics: 0.169636120608
# Take 00:03:55
# Searching 2301bc920194c95cf0c7486e5675243c...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0046750113253070102, 'alpha': 5.8228986979913593}
# CV score: 0.357819953048
# Fit (R2) score: 0.246142544411
# The metrics: 0.344592697686
# Take 00:03:36
# Searching 307afa4120c590b3a46cf4ff5415608a...
# Best Params: {'kernel': 'rbf', 'gamma': 0.015496821809899863, 'alpha': 2.4832517835035626}
# CV score: 0.264228243893
# Fit (R2) score: 0.593354393077
# The metrics: 0.2212392391
# Take 00:04:00
# Searching 929ec6c160e6f52c20a4217c7978f681...
# Best Params: {'kernel': 'rbf', 'gamma': 0.28449713996540432, 'alpha': 4.7095178332209819}
# CV score: 0.904224327569
# Fit (R2) score: 0.112424018527
# The metrics: 0.748345507578
# Take 00:04:03
# Searching 87285a66236346350541b8815c5fae94...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0116464218641541, 'alpha': 2.019800104113366}
# CV score: 0.552201047282
# Fit (R2) score: 0.632267835974
# The metrics: 0.48001394498
# Take 00:03:48
# Searching 8316146a6f78cc6d9f113f0390859417...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0046750113253070102, 'alpha': 0.80260842249730624}
# CV score: 0.142664702153
# Fit (R2) score: 0.347587573098
# The metrics: 0.124498357991
# Take 00:03:52
# Searching 1ecbb52d73c522f184a6fc53128b1ea1...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0116464218641541, 'alpha': 1.4679813551774921}
# CV score: 0.166207124536
# Fit (R2) score: 0.309644928116
# The metrics: 0.140410427467
# Take 00:03:45
# Searching 825a21aa308dea206adb49c4b77c7805...
# Best Params: {'kernel': 'rbf', 'gamma': 0.043838966954732272, 'alpha': 1.0533252209222761}
# CV score: 0.174153499001
# Fit (R2) score: 0.572124598143
# The metrics: 0.107811360324
# Take 00:03:48
# Searching 4725c39a5e5f4c188d382da3910b3f3f...
# Best Params: {'kernel': 'rbf', 'gamma': 0.22031705850211042, 'alpha': 5.4973036418718815}
# CV score: 0.857255613304
# Fit (R2) score: 0.129595067038
# The metrics: 0.726523035896
# Take 00:03:45
# Searching d5cb17978de290c56e84c9cf97e63186...
# Best Params: {'kernel': 'rbf', 'gamma': 0.015496821809899863, 'alpha': 0.80260842249730624}
# CV score: 0.0928856496004
# Fit (R2) score: 0.603409301122
# The metrics: 0.0658472795388
# Take 00:04:07
# Searching 2407d482f0ffa22a947068f2551fe62c...
# Best Params: {'kernel': 'rbf', 'gamma': 0.11912534013182191, 'alpha': 5.4973036418718815}
# CV score: 0.709658210856
# Fit (R2) score: 0.24580940141
# The metrics: 0.605617463518
# Take 00:03:42
# Searching 74c1c25f4b283fa74a5514307b0d0278...
# Best Params: {'kernel': 'rbf', 'gamma': 0.064003279297905336, 'alpha': 3.5015897688863795}
# CV score: 0.623696064624
# Fit (R2) score: 0.301966272792
# The metrics: 0.504528516976
# Take 00:03:36
# Searching ba32abfc048219e933bee869741da911...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0046750113253070102, 'alpha': 4.9217912079777815}
# CV score: 0.17473784485
# Fit (R2) score: 0.0736102484361
# The metrics: 0.167108381448
# Take 00:03:44
# Searching 4b9e4cf2fbdc8281b8a1f9f12b80ce4d...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0116464218641541, 'alpha': 6.8620908425033171}
# CV score: 0.165002814483
# Fit (R2) score: 0.248522021249
# The metrics: 0.154002875203
# Take 00:03:51
# Searching 44c097b7bd219d104050abbafe51bd49...
# Best Params: {'kernel': 'rbf', 'gamma': 0.021924216579518929, 'alpha': 1.6736796710999315}
# CV score: 0.306037959493
# Fit (R2) score: 0.598787647035
# The metrics: 0.233426407843
# Take 00:03:51
# Searching de092beab9305613aca8f79d7d7224e7...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0116464218641541, 'alpha': 1.0841617657114888}
# CV score: 0.147803353799
# Fit (R2) score: 0.447112830414
# The metrics: 0.114803359833
# Take 00:03:38
# Searching 3e12208dd0be281c92a6ab57d9a6fb32...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0116464218641541, 'alpha': 5.7408531756640881}
# CV score: 0.296735398393
# Fit (R2) score: 0.360659530164
# The metrics: 0.27269598437
# Take 00:03:42
# Searching cb6041cc08444746caf6039d8b9e43cb...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0046750113253070102, 'alpha': 2.3353055613925253}
# CV score: 0.18161197023
# Fit (R2) score: 0.318249252091
# The metrics: 0.169212269847
# Take 00:03:52
# Searching 4f8d81b5c31af5d1ba579a65ddc8a5cb...
# Best Params: {'kernel': 'rbf', 'gamma': 0.069870023634668654, 'alpha': 1.8162265969572169}
# CV score: 0.368084012136
# Fit (R2) score: 0.531234493949
# The metrics: 0.246142806242
# Take 00:03:53
# Searching 1c60154546102e6525f68cb4f31e0657...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0046750113253070102, 'alpha': 1.6341399992071393}
# CV score: 0.174749352929
# Fit (R2) score: 0.265601346343
# The metrics: 0.159559610246
# Take 00:03:40
# Searching 3a43dcdff3c0b66b1acb1644ff055f9d...
