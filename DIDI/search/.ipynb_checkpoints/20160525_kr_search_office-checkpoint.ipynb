# %%
import os
from dateutil.parser import parse as dateutil_parse
from six.moves import cPickle as pickle
import time
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler as skStandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.cross_validation import train_test_split,cross_val_score

PATH = '../season_1/'
CLEAN_PATH = PATH+'clean/'

from mylib import myStandardScaler,process_order,process_traffic,get_order_group,get_traffic_group,XY_order_traffic, prediction2submit, Search_Model, DISTRICTS

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
cluster_map = pd.read_csv(CLEAN_PATH+'cluster_map.csv',index_col=0)
poi = pd.read_csv(CLEAN_PATH+'poi.csv',index_col=0)
train_order_group = pd.read_pickle(CLEAN_PATH+'train_order_group.pickle')
test_order_group = pd.read_pickle(CLEAN_PATH+'test_order_group.pickle')
train_traffic_group = pd.read_pickle(CLEAN_PATH+'train_traffic_group.pickle')
test_traffic_group = pd.read_pickle(CLEAN_PATH+'test_traffic_group.pickle')
test_target = pd.read_csv(CLEAN_PATH+'test_target.csv',index_col=0,parse_dates=True)

# %%
train_slot = pd.Index(sorted(train_order_group.values()[0].index.unique()))
train_slot = pd.Index(filter(lambda x: x%1000 >4,train_slot))
test_slot = test_target['datetimeslot']

# %%
now = time.time()

train_XY_group = dict()
for district in DISTRICTS:
    train_XY_group[district] = XY_order_traffic(district,train_order_group,train_traffic_group,train_slot)
test_XY_group = dict()
for district in DISTRICTS:
    test_XY_group[district] = XY_order_traffic(district,test_order_group,test_traffic_group,test_slot)
for district in DISTRICTS:
    scaler = myStandardScaler()
    train_XY_group[district][0] = scaler.fit_transform(train_XY_group[district][0])
    test_XY_group[district][0] = scaler.transform(test_XY_group[district][0])
    
stop = time.time()
print 'Take %02d:%02d:%02d' % ((stop-now)/3600,(stop-now)/60,(stop-now)%60)
# Out:
# Take 00:00:15

# %%
all_now = time.time()

grid_params = {'kernel': ['rbf'],'alpha': np.random.rand(200) * 7,'gamma': np.random.random(200)*1.5}

# grid_params = {'n_estimators': [100] ,'max_depth': [1], 'max_features': ['log2', 'sqrt']}

search_models = {district: Search_Model(KernelRidge) for district in DISTRICTS}
test_prediction = dict()
for district, model in search_models.items():
    now = time.time()
    print 'Searching %s...'%district
    model.fit(grid_params,*train_XY_group[district])
    test_prediction[district] = model.predict(test_XY_group[district][0]) - test_XY_group[district][1].fillna(0)
    with open('kr/test_prediction_%s.pickle'%(district),'wb') as f:
        pickle.dump(test_prediction[district],f)
    stop = time.time()
    print 'Take %02d:%02d:%02d' % ((stop-now)/3600,(stop-now)/60,(stop-now)%60)
    
all_stop = time.time()
print 'Totally take %02d:%02d:%02d' % ((all_stop-all_now)/3600,(all_stop-all_now)/60,(all_stop-all_now)%60)
# Out:
# Searching 38d5ad2d22b61109fd8e7b43cd0e8901...
# Best Params: {'kernel': 'rbf', 'gamma': 0.17361900369172978, 'alpha': 5.1618737738779963}
# CV score: 0.695212751152
# Fit (R2) score: 0.192053021034
# The metrics: 0.577335297756
# Take 00:05:10
# Searching 08f5b445ec6b29deba62e6fd8b0325a6...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0096322166614531968, 'alpha': 3.1614007321028677}
# CV score: 0.159267049791
# Fit (R2) score: 0.331294442309
# The metrics: 0.142838393737
# Take 00:05:32
# Searching 364bf755f9b270f0f9141d1a61de43ee...
# Best Params: {'kernel': 'rbf', 'gamma': 0.08165244742533756, 'alpha': 0.73626638502477604}
# CV score: 0.472393294642
# Fit (R2) score: 0.807314815055
# The metrics: 0.217867705598
# Take 00:05:34
# Searching 49ac89aa860c27e26c0836cb8dab2df2...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 0.72727435016102504}
# CV score: 0.139215248802
# Fit (R2) score: 0.109062809156
# The metrics: 0.136787621427
# Take 00:05:29
# Searching 8bb37d24db1ad665e706c2655d9c4c72...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 4.7932159585716976}
# CV score: 0.252006073678
# Fit (R2) score: 0.188629520971
# The metrics: 0.255179898939
# Take 00:04:52
# Searching dd8d3b9665536d6e05b29c2648c0e69a...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 6.1746501508538865}
# CV score: 0.25901046008
# Fit (R2) score: 0.12552143174
# The metrics: 0.263019595915
# Take 00:05:10
# Searching 08232402614a9b48895cc3d0aeb0e9f2...
# Best Params: {'kernel': 'rbf', 'gamma': 0.013490326942946829, 'alpha': 1.3064867283225974}
# CV score: 0.161575343085
# Fit (R2) score: 0.424501549091
# The metrics: 0.125976443087
# Take 00:05:23
# Searching b702e920dcd2765e624dc1ce3a770512...
# Best Params: {'kernel': 'rbf', 'gamma': 0.074824822148485903, 'alpha': 5.8284984860216182}
# CV score: 0.447966119779
# Fit (R2) score: 0.142002022314
# The metrics: 0.380412264909
# Take 00:05:08
# Searching 52d7b69796362a8ed1691a6cc02ddde4...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 4.956738062891513}
# CV score: 0.168905863818
# Fit (R2) score: 0.0521405594144
# The metrics: 0.167350200281
# Take 00:05:20
# Searching 62afaf3288e236b389af9cfdc5206415...
# Best Params: {'kernel': 'rbf', 'gamma': 0.21330469740225633, 'alpha': 6.7522594906051561}
# CV score: 0.835743145375
# Fit (R2) score: 0.0665943208819
# The metrics: 0.729983262248
# Take 00:05:18
# Searching 445ff793ebd3477d4a2e0b36b2db9271...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 1.762228500265568}
# CV score: 0.110957791486
# Fit (R2) score: 0.0510168166783
# The metrics: 0.109128927112
# Take 00:05:18
# Searching 693a21b16653871bbd455403da5412b4...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0096322166614531968, 'alpha': 4.7932159585716976}
# CV score: 0.290804053988
# Fit (R2) score: 0.32025336163
# The metrics: 0.266184748318
# Take 00:05:16
# Searching a814069db8d32f0fa6e188f41059c6e1...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0096322166614531968, 'alpha': 1.5509628886866174}
# CV score: 0.156682726954
# Fit (R2) score: 0.295480114507
# The metrics: 0.132960269235
# Take 00:04:49
# Searching c9f855e3e13480aad0af64b418e810c3...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0096322166614531968, 'alpha': 1.4129154367728058}
# CV score: 0.161208247164
# Fit (R2) score: 0.511136280338
# The metrics: 0.135142074681
# Take 00:05:39
# Searching 0a5fef95db34383403d11cb6af937309...
# Best Params: {'kernel': 'rbf', 'gamma': 0.013490326942946829, 'alpha': 0.44332340851258489}
# CV score: 0.108776943241
# Fit (R2) score: 0.525922503496
# The metrics: 0.0705264593643
# Take 00:05:27
# Searching ca064c2682ca48c6a21de012e87c0df5...
# Best Params: {'kernel': 'rbf', 'gamma': 0.074824822148485903, 'alpha': 1.8951920122741657}
# CV score: 0.562070799728
# Fit (R2) score: 0.53751990528
# The metrics: 0.384252580768
# Take 00:05:21
# Searching f47f35242ed40655814bc086d7514046...
# Best Params: {'kernel': 'rbf', 'gamma': 0.030599530939811437, 'alpha': 1.3962308001632815}
# CV score: 0.294809714732
# Fit (R2) score: 0.674239512136
# The metrics: 0.202866595594
# Take 00:05:13
# Searching f9280c5dab6910ed44e518248048b9fe...
# Best Params: {'kernel': 'rbf', 'gamma': 0.02320620766767334, 'alpha': 4.1342346639490071}
# CV score: 0.240739302826
# Fit (R2) score: 0.344422758418
# The metrics: 0.206372776454
# Take 00:05:15
# Searching 825c426141df01d38c1b9e9c5330bdac...
# Best Params: {'kernel': 'rbf', 'gamma': 0.013490326942946829, 'alpha': 2.372764092191467}
# CV score: 0.157820427484
# Fit (R2) score: 0.307975521362
# The metrics: 0.132997275958
# Take 00:05:19
# Searching a5609739c6b5c2719a3752327c5e33a7...
# Best Params: {'kernel': 'rbf', 'gamma': 0.08165244742533756, 'alpha': 1.5509628886866174}
# CV score: 0.472739723437
# Fit (R2) score: 0.602156474663
# The metrics: 0.297559096368
# Take 00:04:59
# Searching 90c5a34f06ac86aee0fd70e2adce7d8a...
# Best Params: {'kernel': 'rbf', 'gamma': 0.074824822148485903, 'alpha': 6.3435204949284323}
# CV score: 0.611486572704
# Fit (R2) score: 0.194547404838
# The metrics: 0.533280016498
# Take 00:04:35
# Searching 73ff8ef735e1d68f0cdcbb84d788f2b6...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0096322166614531968, 'alpha': 1.4129154367728058}
# CV score: 0.262644580234
# Fit (R2) score: 0.484324481436
# The metrics: 0.219962275906
# Take 00:05:33
# Searching 1cbfbdd079ef93e74405c53fcfff8567...
# Best Params: {'kernel': 'rbf', 'gamma': 0.013490326942946829, 'alpha': 0.76896796368389397}
# CV score: 0.464692672567
# Fit (R2) score: 0.867457988816
# The metrics: 0.34293089802
# Take 00:05:20
# Searching 52e56004d92b8c74d53e1e42699cba6f...
# Best Params: {'kernel': 'rbf', 'gamma': 0.13724196115297949, 'alpha': 6.0228615639354253}
# CV score: 0.579548748653
# Fit (R2) score: 0.138120723807
# The metrics: 0.501571441454
# Take 00:05:32
# Searching d524868ce69cb9db10fc5af177fb9423...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0097347274517383675, 'alpha': 3.9497627892996192}
# CV score: 0.165980296666
# Fit (R2) score: 0.381842673566
# The metrics: 0.153631137037
# Take 00:05:36
# Searching 3a43dcdff3c0b66b1acb1644ff055f9d...
# Best Params: {'kernel': 'rbf', 'gamma': 0.030599530939811437, 'alpha': 2.8594359311089921}
# CV score: 0.307775005123
# Fit (R2) score: 0.520424244341
# The metrics: 0.242900638931
# Take 00:05:17
# Searching 1c60154546102e6525f68cb4f31e0657...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0096322166614531968, 'alpha': 6.5360268538775355}
# CV score: 0.176345884196
# Fit (R2) score: 0.175864016749
# The metrics: 0.16540723522
# Take 00:05:08
# Searching 4f8d81b5c31af5d1ba579a65ddc8a5cb...
# Best Params: {'kernel': 'rbf', 'gamma': 0.036487931068235002, 'alpha': 3.2560935145510532}
# CV score: 0.353071083615
# Fit (R2) score: 0.461042258329
# The metrics: 0.286966493047
# Take 00:05:10
# Searching cb6041cc08444746caf6039d8b9e43cb...
# Best Params: {'kernel': 'rbf', 'gamma': 0.0097347274517383675, 'alpha': 6.3435204949284323}
# CV score: 0.181918063412
# Fit (R2) score: 0.239199421365
# The metrics: 0.169102417486
# Take 00:05:20
# Searching 3e12208dd0be281c92a6ab57d9a6fb32...
# Best Params: {'kernel': 'rbf', 'gamma': 0.013490326942946829, 'alpha': 5.2091947057277768}
# CV score: 0.29619643129
# Fit (R2) score: 0.365727331399
# The metrics: 0.267507948485
# Take 00:04:52
# Searching de092beab9305613aca8f79d7d7224e7...
# Best Params: {'kernel': 'rbf', 'gamma': 0.013490326942946829, 'alpha': 0.94620426762148568}
# CV score: 0.149235383934
# Fit (R2) score: 0.500068470092
# The metrics: 0.110028514931
# Take 00:05:14
# Searching 44c097b7bd219d104050abbafe51bd49...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 5.9390969299025933}
# CV score: 0.278735915352
# Fit (R2) score: 0.199023534714
# The metrics: 0.282738154054
# Take 00:05:27
# Searching 4b9e4cf2fbdc8281b8a1f9f12b80ce4d...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 1.2405845244539091}
# CV score: 0.151637412094
# Fit (R2) score: 0.154851914524
# The metrics: 0.150350522485
# Take 00:04:46
# Searching ba32abfc048219e933bee869741da911...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 3.9938735395183218}
# CV score: 0.172260988523
# Fit (R2) score: 0.0270341019309
# The metrics: 0.169862951808
# Take 00:05:30
# Searching 74c1c25f4b283fa74a5514307b0d0278...
# Best Params: {'kernel': 'rbf', 'gamma': 0.074824822148485903, 'alpha': 2.6576010317260281}
# CV score: 0.620150881119
# Fit (R2) score: 0.375154926394
# The metrics: 0.468642481747
# Take 00:05:35
# Searching 2407d482f0ffa22a947068f2551fe62c...
# Best Params: {'kernel': 'rbf', 'gamma': 0.11422184747867126, 'alpha': 6.7522594906051561}
# CV score: 0.706993425478
# Fit (R2) score: 0.200864349818
# The metrics: 0.620554321607
# Take 00:05:19
# Searching d5cb17978de290c56e84c9cf97e63186...
# Best Params: {'kernel': 'rbf', 'gamma': 0.00017195856455032299, 'alpha': 6.2843972825413417}
# CV score: 0.0866726800625
# Fit (R2) score:
