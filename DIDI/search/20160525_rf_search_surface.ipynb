# %%
import os
from dateutil.parser import parse as dateutil_parse
from six.moves import cPickle as pickle
import time
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler as skStandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.cross_validation import train_test_split,cross_val_score

PATH = '../season_1/'
CLEAN_PATH = PATH+'clean/'
SEARCH_PATH = 'rf/'

from mylib import myStandardScaler,process_order,process_traffic,get_order_group,get_traffic_group,XY_order_traffic, prediction2submit, Search_Model, DISTRICTS

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
cluster_map = pd.read_csv(CLEAN_PATH+'cluster_map.csv',index_col=0)
poi = pd.read_csv(CLEAN_PATH+'poi.csv',index_col=0)
train_order_group = pd.read_pickle(CLEAN_PATH+'train_order_group.pickle')
test_order_group = pd.read_pickle(CLEAN_PATH+'test_order_group.pickle')
train_traffic_group = pd.read_pickle(CLEAN_PATH+'train_traffic_group.pickle')
test_traffic_group = pd.read_pickle(CLEAN_PATH+'test_traffic_group.pickle')
test_target = pd.read_csv(CLEAN_PATH+'test_target.csv',index_col=0,parse_dates=True)

# %%
train_slot = pd.Index(sorted(train_order_group.values()[0].index.unique()))
train_slot = pd.Index(filter(lambda x: x%1000 >4,train_slot))
test_slot = test_target['datetimeslot']

# %%
now = time.time()

train_XY_group = dict()
for district in DISTRICTS:
    train_XY_group[district] = XY_order_traffic(district,train_order_group,train_traffic_group,train_slot)
test_XY_group = dict()
for district in DISTRICTS:
    test_XY_group[district] = XY_order_traffic(district,test_order_group,test_traffic_group,test_slot)
for district in DISTRICTS:
    scaler = myStandardScaler()
    train_XY_group[district][0] = scaler.fit_transform(train_XY_group[district][0])
    test_XY_group[district][0] = scaler.transform(test_XY_group[district][0])
    
stop = time.time()
print 'Take %02d:%02d:%02d' % ((stop-now)/3600,(stop-now)/60,(stop-now)%60)
# Out:
# Take 00:00:16

# %%
all_now = time.time()

grid_params = {'n_estimators': [150] ,'max_depth': np.arange(8, 21), 'min_samples_leaf': [2,4,6,8,10], 
                     'min_samples_split': [2, 4, 6, 8,10], 'max_features': ['log2', 'sqrt',None]}


# grid_params = {'n_estimators': [1] ,'max_depth': np.arange(1,5), 'min_samples_leaf': np.arange(10,20), 
#                      'min_samples_split': np.arange(10,20), 'max_features': ['log2', 'sqrt',None]}

search_models = {district: Search_Model(RandomForestRegressor) for district in DISTRICTS}
test_prediction = dict()
for district, model in search_models.items()[::-1]:
    if len(os.listdir(SEARCH_PATH))==66:
        print 'We can together! :)'
        break
    now = time.time()
    print 'Searching %s...'%district
    model.fit(grid_params,*train_XY_group[district])
    test_prediction[district] = model.predict(test_XY_group[district][0]) - test_XY_group[district][1].fillna(0)
    with open(SEARCH_PATH+'test_prediction_%s.pickle'%(district),'wb') as f:
        pickle.dump(test_prediction[district],f)
    stop = time.time()
    print 'Take %02d:%02d:%02d' % ((stop-now)/3600,(stop-now)/60,(stop-now)%60)
    
all_stop = time.time()
print 'Totally take %02d:%02d:%02d' % ((all_stop-all_now)/3600,(all_stop-all_now)/60,(all_stop-all_now)%60)
# Out:
# Searching 2350be163432e42270d2670cb3c02f80...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2}
# CV score: 0.199900049525
# Fit (R2) score: 0.275723781711
# The metrics: 0.185343097313
# Take 00:13:55
# Searching 4b7f6f4e2bf237b6cc58f57142bea5c0...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.168672466165
# Fit (R2) score: 0.159553976189
# The metrics: 0.162118365725
# Take 00:15:27
# Searching 82cc4851f9e4faa4e54309f8bb73fd7c...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 18, 'max_features': None, 'min_samples_leaf': 4}
# CV score: 1.00915376509
# Fit (R2) score: 0.963650434583
# The metrics: 0.549001609151
# Take 00:20:14
# Searching 74ec84f1cf75cf89ae176c8c6ceec5ba...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.148582024972
# Fit (R2) score: 0.159172427655
# The metrics: 0.1445398964
# Take 00:13:22
# Searching b05379ac3f9b7d99370d443cfd5dcc28...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 12, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.999878576303
# Fit (R2) score: 0.973560179376
# The metrics: 0.605017431504
# Take 00:22:49
# Searching 2920ece99323b4c111d6f9affc7ea034...
# Best Params: {'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 14, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.931035832044
# Fit (R2) score: 0.932334843037
# The metrics: 0.586756726517
# Take 00:19:11
# Searching 7f84bdfc2b6d4541e1f6c0a3349e0251...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 15, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.118798300012
# Fit (R2) score: 0.396159694646
# The metrics: 0.0953515281533
# Take 00:10:59
# Searching 52a4e8aaa12f70020e889aed8fd5ddbc...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.480565697044
# Fit (R2) score: 0.763778596843
# The metrics: 0.388713933163
# Take 00:17:27
# Searching 4f4041f7db0c7f69892d9b74c1a7efa1...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-4d0d22e76fb8> in <module>()
#      16     now = time.time()
#      17     print 'Searching %s...'%district
# ---> 18     model.fit(grid_params,*train_XY_group[district])
#      19     test_prediction[district] = model.predict(test_XY_group[district][0]) - test_XY_group[district][1].fillna(0)
#      20     with open(SEARCH_PATH+'test_prediction_%s.pickle'%(district),'wb') as f:
#
# C:\Users\jiancheng\Dropbox\search\mylib.pyc in fit(self, search_params, X, Y)
#     186                                        scoring=make_scorer(mymetrics, greater_is_better=False),
#     187                                        cv=5, n_jobs=2)
# --> 188         self.__searcher.fit(X, Y)
#     189         self.best_estimator = self.__searcher.best_estimator_.fit(X, Y)
#     190         prediction = pd.Series(self.best_estimator.predict(X), index=Y.index)
#
# C:\Anaconda2\lib\site-packages\sklearn\grid_search.pyc in fit(self, X, y)
#     994                                           self.n_iter,
#     995                                           random_state=self.random_state)
# --> 996         return self._fit(X, y, sampled_params)
#
# C:\Anaconda2\lib\site-packages\sklearn\grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     551                                     self.fit_params, return_parameters=True,
#     552                                     error_score=self.error_score)
# --> 553                 for parameters in parameter_iterable
#     554                 for train, test in cv)
#     555
#
# C:\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     808                 # consumption.
#     809                 self._iterating = False
# --> 810             self.retrieve()
#     811             # Make sure that we get a last message telling us we are done
#     812             elapsed_time = time.time() - self._start_time
#
# C:\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in retrieve(self)
#     748                 # the results as we will raise the exception we got back
#     749                 # to the caller instead of returning any result.
# --> 750                 self._terminate_pool()
#     751                 if self._managed_pool:
#     752                     # In case we had to terminate a managed pool, let
#
# C:\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _terminate_pool(self)
#     547         if self._pool is not None:
#     548             self._pool.close()
# --> 549             self._pool.terminate()  # terminate does a join()
#     550             self._pool = None
#     551             if self.backend == 'multiprocessing':
#
# C:\Anaconda2\lib\site-packages\sklearn\externals\joblib\pool.pyc in terminate(self)
#     581
#     582     def terminate(self):
# --> 583         super(MemmapingPool, self).terminate()
#     584         delete_folder(self._temp_folder)
#
# C:\Anaconda2\lib\multiprocessing\pool.pyc in terminate(self)
#     463         self._state = TERMINATE
#     464         self._worker_handler._state = TERMINATE
# --> 465         self._terminate()
#     466
#     467     def join(self):
#
# C:\Anaconda2\lib\multiprocessing\util.pyc in __call__(self, wr)
#     205                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     206                           self._callback, self._args, self._kwargs)
# --> 207                 res = self._callback(*self._args, **self._kwargs)
#     208             self._weakref = self._callback = self._args = \
#     209                             self._kwargs = self._key = None
#
# C:\Anaconda2\lib\multiprocessing\pool.pyc in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, worker_handler, task_handler, result_handler, cache)
#     515         debug('joining task handler')
#     516         if threading.current_thread() is not task_handler:
# --> 517             task_handler.join(1e100)
#     518
#     519         debug('joining result handler')
#
# C:\Anaconda2\lib\threading.pyc in join(self, timeout)
#     949                             self._note("%s.join(): timed out", self)
#     950                         break
# --> 951                     self.__block.wait(delay)
#     952                 else:
#     953                     if __debug__:
#
# C:\Anaconda2\lib\threading.pyc in wait(self, timeout)
#     357                         break
#     358                     delay = min(delay * 2, remaining, .05)
# --> 359                     _sleep(delay)
#     360                 if not gotit:
#     361                     if __debug__:
#
# KeyboardInterrupt:

# %%
pickle_path = SEARCH_PATH
pickle_all = dict()
for pkl in os.listdir(pickle_path):
    pickle_all[pkl.split('_')[-1].split('.')[0]] = pd.read_pickle(pickle_path+pkl)
print 'Have already pickled %d'%len(pickle_all)
# Out:
# Have already pickled 66

# %%
res = prediction2submit(pickle_all,cluster_map)
res
# Out:
#               district             dts  prediction
# datetimeslot
# 20160122046          1   2016-01-22-46    7.498345
# 20160122046          2   2016-01-22-46    0.443821
# 20160122046          3   2016-01-22-46    0.743585
# 20160122046          4   2016-01-22-46   16.385130
# 20160122046          5   2016-01-22-46    0.908673
# 20160122046          6   2016-01-22-46   10.244347
# 20160122046          7   2016-01-22-46   39.033285
# 20160122046          8   2016-01-22-46  270.705463
