# %%
import os
from dateutil.parser import parse as dateutil_parse
from six.moves import cPickle as pickle
import time
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler as skStandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.cross_validation import train_test_split,cross_val_score

PATH = '../season_1/'
CLEAN_PATH = PATH+'clean/'
SEARCH_PATH = 'rf/'

from mylib import myStandardScaler,process_order,process_traffic,get_order_group,get_traffic_group,XY_order_traffic, prediction2submit, Search_Model, DISTRICTS

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
cluster_map = pd.read_csv(CLEAN_PATH+'cluster_map.csv',index_col=0)
poi = pd.read_csv(CLEAN_PATH+'poi.csv',index_col=0)
train_order_group = pd.read_pickle(CLEAN_PATH+'train_order_group.pickle')
test_order_group = pd.read_pickle(CLEAN_PATH+'test_order_group.pickle')
train_traffic_group = pd.read_pickle(CLEAN_PATH+'train_traffic_group.pickle')
test_traffic_group = pd.read_pickle(CLEAN_PATH+'test_traffic_group.pickle')
test_target = pd.read_csv(CLEAN_PATH+'test_target.csv',index_col=0,parse_dates=True)

# %%
train_slot = pd.Index(sorted(train_order_group.values()[0].index.unique()))
train_slot = pd.Index(filter(lambda x: x%1000 >4,train_slot))
test_slot = test_target['datetimeslot']

# %%
now = time.time()

train_XY_group = dict()
for district in DISTRICTS:
    train_XY_group[district] = XY_order_traffic(district,train_order_group,train_traffic_group,train_slot)
test_XY_group = dict()
for district in DISTRICTS:
    test_XY_group[district] = XY_order_traffic(district,test_order_group,test_traffic_group,test_slot)
for district in DISTRICTS:
    scaler = myStandardScaler()
    train_XY_group[district][0] = scaler.fit_transform(train_XY_group[district][0])
    test_XY_group[district][0] = scaler.transform(test_XY_group[district][0])
    
stop = time.time()
print 'Take %02d:%02d:%02d' % ((stop-now)/3600,(stop-now)/60,(stop-now)%60)
# Out:
# Take 00:00:16

# %%
all_now = time.time()

grid_params = {'n_estimators': [150] ,'max_depth': np.arange(8, 21), 'min_samples_leaf': [2,4,6,8,10], 
                     'min_samples_split': [2, 4, 6, 8,10], 'max_features': ['log2', 'sqrt',None]}


# grid_params = {'n_estimators': [1] ,'max_depth': np.arange(1,5), 'min_samples_leaf': np.arange(10,20), 
#                      'min_samples_split': np.arange(10,20), 'max_features': ['log2', 'sqrt',None]}

search_models = {district: Search_Model(RandomForestRegressor) for district in DISTRICTS}
test_prediction = dict()
for district, model in search_models.items():
    if len(os.listdir(SEARCH_PATH))==66:
        print 'We can together! :)'
        break
    now = time.time()
    print 'Searching %s...'%district
    model.fit(grid_params,*train_XY_group[district])
    test_prediction[district] = model.predict(test_XY_group[district][0]) - test_XY_group[district][1].fillna(0)
    with open(SEARCH_PATH+'test_prediction_%s.pickle'%(district),'wb') as f:
        pickle.dump(test_prediction[district],f)
    stop = time.time()
    print 'Take %02d:%02d:%02d' % ((stop-now)/3600,(stop-now)/60,(stop-now)%60)
    
all_stop = time.time()
print 'Totally take %02d:%02d:%02d' % ((all_stop-all_now)/3600,(all_stop-all_now)/60,(all_stop-all_now)%60)
# Out:
# Searching 38d5ad2d22b61109fd8e7b43cd0e8901...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 11, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.827183252496
# Fit (R2) score: 0.940936710761
# The metrics: 0.566260754787
# Take 00:15:00
# Searching 08f5b445ec6b29deba62e6fd8b0325a6...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 8}
# CV score: 0.140749113321
# Fit (R2) score: 0.349412566368
# The metrics: 0.135748144719
# Take 00:08:58
# Searching 364bf755f9b270f0f9141d1a61de43ee...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2}
# CV score: 0.538026375951
# Fit (R2) score: 0.730906719042
# The metrics: 0.443226428503
# Take 00:13:11
# Searching 49ac89aa860c27e26c0836cb8dab2df2...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 6}
# CV score: 0.136665764405
# Fit (R2) score: 0.266260077267
# The metrics: 0.121697737308
# Take 00:07:27
# Searching 8bb37d24db1ad665e706c2655d9c4c72...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.260051916639
# Fit (R2) score: 0.285239812238
# The metrics: 0.249343292695
# Take 00:08:38
# Searching dd8d3b9665536d6e05b29c2648c0e69a...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 6}
# CV score: 0.25266119693
# Fit (R2) score: 0.324897870468
# The metrics: 0.236938948144
# Take 00:12:06
# Searching 08232402614a9b48895cc3d0aeb0e9f2...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 8}
# CV score: 0.147748390554
# Fit (R2) score: 0.40961856014
# The metrics: 0.112105032883
# Take 00:09:33
# Searching b702e920dcd2765e624dc1ce3a770512...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.482111440474
# Fit (R2) score: 0.68659085845
# The metrics: 0.388156944232
# Take 00:11:49
# Searching 52d7b69796362a8ed1691a6cc02ddde4...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.165719129281
# Fit (R2) score: 0.140591464866
# The metrics: 0.15829332415
# Take 00:10:01
# Searching 62afaf3288e236b389af9cfdc5206415...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 10}
# CV score: 1.04516732515
# Fit (R2) score: 0.894267695165
# The metrics: 0.724630153568
# Take 00:14:17
# Searching 445ff793ebd3477d4a2e0b36b2db9271...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.106240346421
# Fit (R2) score: 0.35797353352
# The metrics: 0.0851826007061
# Take 00:09:15
# Searching 693a21b16653871bbd455403da5412b4...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2}
# CV score: 0.284662018707
# Fit (R2) score: 0.641090344587
# The metrics: 0.252531283846
# Take 00:10:55
# Searching a814069db8d32f0fa6e188f41059c6e1...
# Best Params: {'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 18, 'max_features': 'sqrt', 'min_samples_leaf': 2}
# CV score: 0.147315014909
# Fit (R2) score: 0.451038583964
# The metrics: 0.11246581127
# Take 00:10:48
# Searching c9f855e3e13480aad0af64b418e810c3...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 12, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.145934260981
# Fit (R2) score: 0.210916837053
# The metrics: 0.140803693972
# Take 00:08:38
# Searching 0a5fef95db34383403d11cb6af937309...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4}
# CV score: 0.100327424792
# Fit (R2) score: 0.417793398963
# The metrics: 0.0777701482983
# Take 00:07:13
# Searching ca064c2682ca48c6a21de012e87c0df5...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 10}
# CV score: 0.645054311057
# Fit (R2) score: 0.776225613603
# The metrics: 0.570374433656
# Take 00:14:41
# Searching f47f35242ed40655814bc086d7514046...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.265848123765
# Fit (R2) score: 0.894290843177
# The metrics: 0.187944670257
# Take 00:10:21
# Searching f9280c5dab6910ed44e518248048b9fe...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 11, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.202143502031
# Fit (R2) score: 0.271245144284
# The metrics: 0.193109627347
# Take 00:11:30
# Searching 825c426141df01d38c1b9e9c5330bdac...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 19, 'max_features': None, 'min_samples_leaf': 10}
# CV score: 0.143678059873
# Fit (R2) score: 0.37254433456
# The metrics: 0.111664354383
# Take 00:09:13
# Searching a5609739c6b5c2719a3752327c5e33a7...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 4}
# CV score: 0.478825121303
# Fit (R2) score: 0.835984438368
# The metrics: 0.393379719002
# Take 00:12:51
# Searching 90c5a34f06ac86aee0fd70e2adce7d8a...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 14, 'max_features': None, 'min_samples_leaf': 10}
# CV score: 0.789710560246
# Fit (R2) score: 0.527263025294
# The metrics: 0.584814210101
# Take 00:14:11
# Searching 73ff8ef735e1d68f0cdcbb84d788f2b6...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 19, 'max_features': 'log2', 'min_samples_leaf': 8}
# CV score: 0.237901436267
# Fit (R2) score: 0.26855437052
# The metrics: 0.223703241378
# Take 00:08:40
# Searching 1cbfbdd079ef93e74405c53fcfff8567...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.426134632471
# Fit (R2) score: 0.913620086583
# The metrics: 0.303562916975
# Take 00:11:36
# Searching 52e56004d92b8c74d53e1e42699cba6f...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 12, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.692327536989
# Fit (R2) score: 0.952005395291
# The metrics: 0.414978506138
# Take 00:12:49
# Searching d524868ce69cb9db10fc5af177fb9423...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 11, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.147689911194
# Fit (R2) score: 0.237622188602
# The metrics: 0.144845845886
# Take 00:10:14
# Searching 3a43dcdff3c0b66b1acb1644ff055f9d...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.28939659132
# Fit (R2) score: 0.780444399842
# The metrics: 0.23975953684
# Take 00:13:28
# Searching 1c60154546102e6525f68cb4f31e0657...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 19, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.159100354514
# Fit (R2) score: 0.170491534642
# The metrics: 0.151068563097
# Take 00:09:27
# Searching 4f8d81b5c31af5d1ba579a65ddc8a5cb...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2}
# CV score: 0.314251160124
# Fit (R2) score: 0.73457055629
# The metrics: 0.253553623609
# Take 00:09:34
# Searching cb6041cc08444746caf6039d8b9e43cb...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.156351782741
# Fit (R2) score: 0.186480716032
# The metrics: 0.150530348957
# Take 00:08:42
# Searching 3e12208dd0be281c92a6ab57d9a6fb32...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.276171789662
# Fit (R2) score: 0.687427307476
# The metrics: 0.214722211871
# Take 00:10:56
# Searching de092beab9305613aca8f79d7d7224e7...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 19, 'max_features': None, 'min_samples_leaf': 8}
# CV score: 0.138923730099
# Fit (R2) score: 0.394882596946
# The metrics: 0.104641401974
# Take 00:09:24
# Searching 44c097b7bd219d104050abbafe51bd49...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 11, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.290154237021
# Fit (R2) score: 0.342677577395
# The metrics: 0.272878979141
# Take 00:11:30
# Searching 4b9e4cf2fbdc8281b8a1f9f12b80ce4d...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 8}
# CV score: 0.137746438005
# Fit (R2) score: 0.179400280943
# The metrics: 0.133430212643
# Take 00:09:10
# Searching ba32abfc048219e933bee869741da911...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 19, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.166835302718
# Fit (R2) score: 0.38567438498
# The metrics: 0.123041094129
# Take 00:11:29
# Searching 74c1c25f4b283fa74a5514307b0d0278...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 16, 'max_features': None, 'min_samples_leaf': 4}
# CV score: 0.729334077394
# Fit (R2) score: 0.76122217714
# The metrics: 0.50814297379
# Take 00:13:35
# Searching 2407d482f0ffa22a947068f2551fe62c...
# Best Params: {'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 16, 'max_features': None, 'min_samples_leaf': 4}
# CV score: 0.932502567765
# Fit (R2) score: 0.944567990822
# The metrics: 0.61391918555
# Take 00:19:07
# Searching d5cb17978de290c56e84c9cf97e63186...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 18, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.0814657951763
# Fit (R2) score: 0.497312710757
# The metrics: 0.0687907745916
# Take 00:07:39
# Searching 4725c39a5e5f4c188d382da3910b3f3f...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 17, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 1.03635233722
# Fit (R2) score: 0.942451199852
# The metrics: 0.621703277872
# Take 00:15:11
# Searching 825a21aa308dea206adb49c4b77c7805...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.148030204654
# Fit (R2) score: 0.418310504567
# The metrics: 0.105163177651
# Take 00:09:03
# Searching 1ecbb52d73c522f184a6fc53128b1ea1...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2}
# CV score: 0.15778867005
# Fit (R2) score: 0.496193122527
# The metrics: 0.11438992527
# Take 00:12:53
# Searching 8316146a6f78cc6d9f113f0390859417...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 18, 'max_features': 'sqrt', 'min_samples_leaf': 4}
# CV score: 0.132251584748
# Fit (R2) score: 0.352100470135
# The metrics: 0.114100004826
# Take 00:10:05
# Searching 87285a66236346350541b8815c5fae94...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.548656843574
# Fit (R2) score: 0.731387432716
# The metrics: 0.430513116816
# Take 00:11:55
# Searching 929ec6c160e6f52c20a4217c7978f681...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 17, 'max_features': None, 'min_samples_leaf': 4}
# CV score: 1.10400316765
# Fit (R2) score: 0.943010467086
# The metrics: 0.586975908355
# Take 00:18:24
# Searching 307afa4120c590b3a46cf4ff5415608a...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2}
# CV score: 0.198176554438
# Fit (R2) score: 0.572152197675
# The metrics: 0.180527546383
# Take 00:10:29
# Searching 2301bc920194c95cf0c7486e5675243c...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.342366133944
# Fit (R2) score: 0.237613139803
# The metrics: 0.330561555131
# Take 00:11:24
# Searching bf44d327f0232325c6d5280926d7b37d...
# Best Params: {'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 8}
# CV score: 0.179984163553
# Fit (R2) score: 0.356891753361
# The metrics: 0.132484012483
# Take 00:11:47
# Searching fc34648599753c9e74ab238e9a4a07ad...
# Best Params: {'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 16, 'max_features': None, 'min_samples_leaf': 6}
# CV score: 0.752879987519
# Fit (R2) score: 0.74339764217
# The metrics: 0.44792150046
# Take 00:13:46
# Searching d4ec2125aff74eded207d2d915ef682f...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 18, 'max_features': None, 'min_samples_leaf': 4}
# CV score: 0.893196674589
# Fit (R2) score: 0.960867710358
# The metrics: 0.43512867861
# Take 00:18:11
# Searching a735449c5c09df639c35a7d61fad3ee5...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4}
# CV score: 0.110103003789
# Fit (R2) score: 0.514127600477
# The metrics: 0.0807975016098
# Take 00:07:42
# Searching 58c7a4888306d8ff3a641d1c0feccbe3...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 14, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.15143248667
# Fit (R2) score: 0.156170068448
# The metrics: 0.145365895412
# Take 00:10:23
# Searching 1afd7afbc81ecc1b13886a569d869e8a...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 16, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.873519215626
# Fit (R2) score: 0.977816998788
# The metrics: 0.459209589706
# Take 00:14:58
# Searching 91690261186ae5bee8f83808ea1e4a01...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 19, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.752798279337
# Fit (R2) score: 0.949862490956
# The metrics: 0.379515800917
# Take 00:15:13
# Searching d05052b4bda7662a084f235e880f50fa...
# Best Params: {'n_estimators': 150, 'min_samples_split': 6, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.214195935846
# Fit (R2) score: 0.263036742972
# The metrics: 0.201677090845
# Take 00:11:33
# Searching c4ec24e0a58ebedaa1661e5c09e47bb5...
# Best Params: {'n_estimators': 150, 'min_samples_split': 8, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 10}
# CV score: 0.186201776008
# Fit (R2) score: 0.269497874713
# The metrics: 0.150765131958
# Take 00:08:34
# Searching f2c8c4bb99e6377d21de71275afd6cd2...
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.179574707506
# Fit (R2) score: 0.148430424
# The metrics: 0.170956050291
# Take 00:10:51
# Searching fff4e8465d1e12621bc361276b6217cf...
# Best Params: {'n_estimators': 150, 'min_samples_split': 10, 'max_depth': 11, 'max_features': 'sqrt', 'min_samples_leaf': 10}
# CV score: 0.159251925177
# Fit (R2) score: 0.184655653974
# The metrics: 0.148287586105
# Take 00:08:27
# Searching b26a240205c852804ff8758628c0a86a...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 14, 'max_features': None, 'min_samples_leaf': 2}
# CV score: 0.740973067437
# Fit (R2) score: 0.957948827231
# The metrics: 0.467911588841
# Take 00:13:08
# Searching 4f4041f7db0c7f69892d9b74c1a7efa1...
# Best Params: {'n_estimators': 150, 'min_samples_split': 2, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 10}
# CV score: 0.177532993742
# Fit (R2) score: 0.32666791025
# The metrics: 0.171999298331
# Take 00:07:13
# We can together! :)
# Totally take 10:659:32

# %%
pickle_path = SEARCH_PATH
pickle_all = dict()
for pkl in os.listdir(pickle_path):
    pickle_all[pkl.split('_')[-1].split('.')[0]] = pd.read_pickle(pickle_path+pkl)
print 'Have already pickled %d'%len(pickle_all)
# Out:
# Have already pickled 66

# %%
prediction2submit(pickle_all,cluster_map)
# Out:
#               district             dts  prediction
# datetimeslot
# 20160122046          1   2016-01-22-46    7.498345
# 20160122046          2   2016-01-22-46    0.443821
# 20160122046          3   2016-01-22-46    0.743585
# 20160122046          4   2016-01-22-46   16.385130
# 20160122046          5   2016-01-22-46    0.908673
# 20160122046          6   2016-01-22-46   10.244347
# 20160122046          7   2016-01-22-46   39.033285
# 20160122046          8   2016-01-22-46  270.705463
# 20160122046          9   2016-01-22-46    2.863952
# 20160122046         10   2016-01-22-46    2.310059
# 20160122046         11   2016-01-22-46    2.613499
# 20160122046         12   2016-01-22-46   17.321719
# 20160122046         13   2016-01-22-46    1.006975
# 20160122046         14   2016-01-22-46   88.230115
# 20160122046         15   2016-01-22-46    0.078296
# 20160122046         16   2016-01-22-46    1.144118
# 20160122046         17   2016-01-22-46    0.485871
# 20160122046         18   2016-01-22-46    1.728037
# 20160122046         19   2016-01-22-46    1.909945
# 20160122046         20   2016-01-22-46    5.273286
# 20160122046         21   2016-01-22-46    3.518430
# 20160122046         22   2016-01-22-46    4.939340
# 20160122046         23   2016-01-22-46  108.842725
# 20160122046         24   2016-01-22-46  155.250360
# 20160122046         25   2016-01-22-46    1.114986
# 20160122046         26   2016-01-22-46   10.776325
# 20160122046         27   2016-01-22-46   14.382889
# 20160122046         28   2016-01-22-46   13.491500
# 20160122046         29   2016-01-22-46    4.081729
# 20160122046         30   2016-01-22-46    0.611183
# ...                ...             ...         ...
# 20160130142         37  2016-01-30-142    5.467120
# 20160130142         38  2016-01-30-142    1.159652
# 20160130142         39  2016-01-30-142    1.792761
# 20160130142         40  2016-01-30-142    1.067860
# 20160130142         41  2016-01-30-142    0.785338
# 20160130142         42  2016-01-30-142    2.410714
# 20160130142         43  2016-01-30-142    0.275734
# 20160130142         44  2016-01-30-142    0.527948
# 20160130142         45  2016-01-30-142    0.555133
# 20160130142         46  2016-01-30-142    2.334663
# 20160130142         47  2016-01-30-142    1.385761
# 20160130142         48  2016-01-30-142    9.402612
# 20160130142         49  2016-01-30-142    0.581624
# 20160130142         50  2016-01-30-142    0.562915
# 20160130142         51  2016-01-30-142  123.073680
# 20160130142         52  2016-01-30-142    0.137984
# 20160130142         53  2016-01-30-142    0.735800
# 20160130142         54  2016-01-30-142    0.837298
# 20160130142         55  2016-01-30-142    0.415849
# 20160130142         56  2016-01-30-142    0.476305
# 20160130142         57  2016-01-30-142    0.230006
# 20160130142         58  2016-01-30-142    0.511515
# 20160130142         59  2016-01-30-142    0.442722
# 20160130142         60  2016-01-30-142    0.148593
# 20160130142         61  2016-01-30-142    0.253284
# 20160130142         62  2016-01-30-142    0.253177
# 20160130142         63  2016-01-30-142    0.071812
# 20160130142         64  2016-01-30-142    0.381193
# 20160130142         65  2016-01-30-142    0.516716
# 20160130142         66  2016-01-30-142    0.322448
#
# [2838 rows x 3 columns]
