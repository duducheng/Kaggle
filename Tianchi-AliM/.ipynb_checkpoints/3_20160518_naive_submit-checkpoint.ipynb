# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse as dateutil_parser

from sklearn.preprocessing import StandardScaler as skStandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV

DATA_PATH = './data/'

# %matplotlib inline

# %%
clean_play = pd.read_csv(DATA_PATH+'naive/play.csv',index_col=0)
clean_download = pd.read_csv(DATA_PATH+'naive/download.csv',index_col=0)
clean_like = pd.read_csv(DATA_PATH+'naive/like.csv',index_col=0)
song = pd.read_csv(DATA_PATH+'mars_tianchi_songs.csv')

# %%
song.index = song.song_id
all_songs = song.loc[:,['song_init_plays']]
all_songs['howold'] = (song['publish_time'].map(lambda x: dateutil_parser(str(x))) - dateutil_parser('20150301')).map(lambda x: x.days)
lang = pd.get_dummies(song['Language'],'lang').applymap(lambda x: True if x==1 else False)
gender = pd.get_dummies(song['Gender'],'gender').applymap(lambda x: True if x==1 else False)
dummy_features = lang.columns.union(gender.columns)
all_songs = pd.concat([all_songs,lang,gender],axis=1)

# %%
class myStandardScaler(skStandardScaler):
    '''
    Only use fit_transform and tranform.
    And only deal with pd.DataFrame
    '''
    def fit_transform(self, X):
        Xnumerical = X[X.columns[X.dtypes != bool]]
        Xdummy = X[X.columns[X.dtypes == bool]]
        scaledXnumerical = super(myStandardScaler, self).fit_transform(Xnumerical)
        Xnumerical = pd.DataFrame(scaledXnumerical, index=Xnumerical.index, columns=Xnumerical.columns)
        return pd.concat([Xnumerical, Xdummy], axis=1)

    def transform(self, X):
        Xnumerical = X[X.columns[X.dtypes != bool]]
        Xdummy = X[X.columns[X.dtypes == bool]]
        scaledXnumerical = super(myStandardScaler, self).transform(Xnumerical)
        Xnumerical = pd.DataFrame(scaledXnumerical, index=Xnumerical.index, columns=Xnumerical.columns)
        return pd.concat([Xnumerical, Xdummy], axis=1)

# %%
train_play = clean_play.iloc[:,:-61].rename(columns=lambda x: str(x)+'_play')
train_download = clean_download.iloc[:,:-61].rename(columns=lambda x: str(x)+'_download')
train_like = clean_like.iloc[:,:-61].rename(columns=lambda x: str(x)+'_like')

Xtrain = pd.concat([all_songs,train_play,train_download,train_like],axis=1).fillna(0)
Ytrain = pd.concat([pd.DataFrame(index=all_songs.index),clean_play.iloc[:,-60:]],axis=1).fillna(0)

test_play = clean_play.iloc[:,61:].rename(columns=lambda x: str(x)+'_play')
test_download = clean_download.iloc[:,61:].rename(columns=lambda x: str(x)+'_download')
test_like = clean_like.iloc[:,61:].rename(columns=lambda x: str(x)+'_like')
Xtest = pd.concat([all_songs,test_play,test_download,test_like],axis=1).fillna(0)

# %%
scaler = myStandardScaler()
Xtrain = scaler.fit_transform(Xtrain)
Xtest = scaler.transform(Xtest)

# %%
# Ytest = pd.DataFrame(prediction.values, index=all_songs.index, columns = pd.date_range('20150901','20151031'))

# %%
rfr = RandomForestRegressor(50, max_features='log2')

# %%
val_scores = cross_val_score(rfr, Xtrain, Ytrain, scoring='mean_squared_error')
val_scores
# Out:
# array([-514.32314585, -776.45385008,  -72.76189033])

# %%
rfr = RandomForestRegressor(50, max_features='auto')
val_scores = cross_val_score(rfr, Xtrain, Ytrain, scoring='mean_squared_error')
val_scores
# Out:
# array([-602.20922054, -954.33056505,  -92.1670713 ])

# %%
rfr = RandomForestRegressor(50, max_features='sqrt')
val_scores = cross_val_score(rfr, Xtrain, Ytrain, scoring='mean_squared_error')
val_scores
# Out:
# array([-529.65619728, -777.00277329,  -97.46682647])

# %%
pd.Series([-602.20922054, -954.33056505,  -92.1670713 ]).mean()
# Out:
# -549.5689522966667

# %%
pd.Series([-514.32314585, -776.45385008,  -72.76189033]).mean()
# Out:
# -454.5129620866666

# %%
pd.Series([-529.65619728, -777.00277329,  -97.46682647]).mean()
# Out:
# -468.0419323466667

# %%
rfr = RandomForestRegressor(50, max_features='log2').fit(Xtrain, Ytrain)

# %%
rfr.score(Xtrain,Ytrain)
# Out:
# 0.92423333274212682

# %%
Ytest = pd.DataFrame(rfr.predict(Xtest), index=all_songs.index, columns = pd.date_range('20150901','20151030'))

# %%
Ytest.sum(axis=1)['7ec488fc483386cdada5448864e82990']
# Out:
# 3.0400000000000014

# %%
clean_play.sum(axis=1).argmax()
# Out:
# '7ec488fc483386cdada5448864e82990'

# %%
song2artist = pd.concat([song['artist_id'],Ytest], axis=1)

# %%
artist = song2artist.groupby('artist_id').sum().applymap(lambda x: int(x+0.5))

# %%
artist.iloc[0,:].plot()

# %%
artist.iloc[1,:].plot()

# %%
artist.iloc[2,:].plot()

# %%
artist.iloc[3,:].plot()

# %%
artist.iloc[4,:].plot()

# %%
artist.iloc[5,:].plot()

# %%
artist.iloc[6,:].plot()

# %%
fig, axes = plt.subplots(50,1, figsize=(10,200))
for i in range(50):
    artist.iloc[i,:].plot(ax=axes[i])

# %%
# artist.columns = artist.columns.map(lambda x: x.date())
artist.stack().to_csv('submit.csv')

# %%
artist.sum(axis=1).sort_values()
# Out:
# artist_id
# 9f69ffd8852196e02cfa19b5cd9bc432      1010
# b6a175a48743caed6d035444c069ab64      1025
# 023406156015ef87f99521f3b343f71f      1404
# 8fb3cef29f2c266af4c9ecef3b780e97      1484
# f5a5373f30de984e9142a206f94a2f46      1755
# 40bbb0da5570702dd6ff3af5e9e3aea6      2549
# 53dd7de874e0999634c28cdd94d21257      3529
# 3964ee41d4e2ade1957a9135afe1b8dc      4406
# 1731019fbaa825714d5f8e61ad1bb7ff      4661
# bf21d16799b240d6e445fa30472bd50b      6301
# 2b7fedeea967becd9408b896de8ff903      6995
# 8da51d03b8b8717431e8b902856fb45e      9012
# 7e0db58c13d033dafe5f5e1e70ff7eb4      9067
# d773376e46311393cd89994bf9a93043      9423
# 03c6699ea836decbc5c8fc2dbae7bd3b     10452
# 4ee3f9c90101073c99d5440b41f07daa     11478
# c026b84e8f23a7741d9b670e3d8973f0     11544
# f6e0f05fde7637afb8f8bc6bda74ca24     12392
# 8f29cbc2a555034643d66f9e83dd7a7a     12510
# 6f462b173b2d6d20a2c9fb1ec0fd2dda     13240
# 445a257964b9689f115a69e8cc5dcb75     14000
# 2ec1450a1389d4e3fc2a9a76c9378bb3     14463
# ca6db6d4f02b7b946c57fc389e67dd7e     14894
# 025943df23acf5d3863b35fa6e0d79ec     18587
# 099cd99056bf92e5f0e384465890a804     18628
# ffd47cf9cb66d226575336f0fa42ae25     19083
# 33fd0a2cfcfd24e114707bba71ca1de9     20894
# 28e32be6ba67e0c6fdfdff80ce07dfd4     21004
# 61dfd882204789d7d0f70fee2b901cef     24349
# 0c80008b0a28d356026f4b1097041689     26296
# 9e58afbf3fea116b0050bf56bfb4442e     26803
# 1339f978614ff19cd48f07e5420556d4     26858
# 5e2ef5473cbbdb335f6d51dc57845437     30120
# 4f3f68292e50f39cd8142733512c07d6     38800
# 97de6333157f35467dff271d7afb0a23     39034
# be0c7a23c2aa9afb45163995b9ec938c     39889
# 82fda1f850a9fe22e41b5c8dadaff4ac     42168
# 3e395c6b799d3d8cb7cd501b4503b536     49255
# 6a493121e53d83f9e119b02942d7c8fe     50953
# e6e2fff03cc32ee9777de2c2ed5bac30     51645
# 34bc4bc49a725f2686a5cf9c89985798     56803
# e087f8842fe66efa5ccee42ff791e0ca     66591
# b7522cc91cf57ada15de2298bfd6a3ee     70202
# 6bb4c3bbdb6f5a96d643320c6b6005f5     74178
# ac43c6ce2f9df4adfbb05edd97cecbcc     77733
# c5eac1d455675dfbc99f6c70f7b3971f     99924
# c5f0170f87a2fbb17bf65dc858c745e2    138208
# 25739ad1c56a511fcac86018ac4e49bb    139150
# 2e14d32266ee6b4678595f8f50c369ac    140697
# 4b8eb68442432c242e9242be040bacf9    373761
# dtype: int64

# %%
song[song.artist_id=='2e14d32266ee6b4678595f8f50c369ac']
# Out:
#                                                            song_id  \
# song_id
# 8c0af7b6cb812288cee966a8fa4bb0d4  8c0af7b6cb812288cee966a8fa4bb0d4
# 7c681d27bf5d684f2c188611653ebf0f  7c681d27bf5d684f2c188611653ebf0f
# 43859bd7584a7aa43a28a7b05def5171  43859bd7584a7aa43a28a7b05def5171
# dbf76bdb58c5249c5c94acf59a6ccb71  dbf76bdb58c5249c5c94acf59a6ccb71
# 2af2818aad07f8725188b43a01fc9a6c  2af2818aad07f8725188b43a01fc9a6c
# 8c508dfa4dce1e62c8e932651f395df5  8c508dfa4dce1e62c8e932651f395df5
# 2d81384605726b0bb2cf63208ba5ddd7  2d81384605726b0bb2cf63208ba5ddd7
# a1d22987106e889ec73143f56dca538b  a1d22987106e889ec73143f56dca538b
# 8c8b30ec87c2e79245e48fd67e9eb199  8c8b30ec87c2e79245e48fd67e9eb199
# 3cb17112b2775dd44aec81ccec55d499  3cb17112b2775dd44aec81ccec55d499
# 217396be947552523444055f0abab369  217396be947552523444055f0abab369
# 3de62f03b08964d37079230d6eed9b4f  3de62f03b08964d37079230d6eed9b4f
# bec08290e3dbf0e059d8772bbb40d755  bec08290e3dbf0e059d8772bbb40d755
# 241b146e6b7c30e64d02699f6f2f9ebe  241b146e6b7c30e64d02699f6f2f9ebe
# cf3db2de287f966839bbdacc1f534298  cf3db2de287f966839bbdacc1f534298
# 9bc42c527ba9f7780de3e78876d13a16  9bc42c527ba9f7780de3e78876d13a16
# e4b2f80335d12fe1cb841f904b34d007  e4b2f80335d12fe1cb841f904b34d007
# 91551efd4a3a45e7488b30a50a662ed5  91551efd4a3a45e7488b30a50a662ed5
# 2a87b8eb06f111d7d289b79c3242b12c  2a87b8eb06f111d7d289b79c3242b12c
# 60ce8fed0592407b882b3f171a2686d8  60ce8fed0592407b882b3f171a2686d8
# c6491cda718afb65f7e5c08172315a6c  c6491cda718afb65f7e5c08172315a6c
# 76a29e7c057b41f72f21cfc4d710d577  76a29e7c057b41f72f21cfc4d710d577
# 4d98fdab5930d2feb2084ebfdb01fc88  4d98fdab5930d2feb2084ebfdb01fc88
# b0074843cd57e8d7ea23dea663e72467  b0074843cd57e8d7ea23dea663e72467
# f0ff0838ef045952d691673158c8eb44  f0ff0838ef045952d691673158c8eb44
# 0a6f8c28aa062602fbcee3cebd440968  0a6f8c28aa062602fbcee3cebd440968
# 3ccf6c61816550612e19b0b9b0470234  3ccf6c61816550612e19b0b9b0470234
# 1c733936d1bb83aff7219e3b1a936a2f  1c733936d1bb83aff7219e3b1a936a2f
# 40e0b72302cb8003c2b3479866b1703e  40e0b72302cb8003c2b3479866b1703e
# ed7499bd2f9a6e35c20a364655c33d01  ed7499bd2f9a6e35c20a364655c33d01
# ...                                                            ...
# 5421e28cc36c3ca5b9ccff8ba2c104a3  5421e28cc36c3ca5b9ccff8ba2c104a3
# 2e7d4a5b476cf385382776f30764415b  2e7d4a5b476cf385382776f30764415b
# 8102a76d4371894641cf62719147650e  8102a76d4371894641cf62719147650e
# 7ff17510540bfe3f8ba07a6d71fb252d  7ff17510540bfe3f8ba07a6d71fb252d
# 58b5c324003c786ea67b27c71ab18044  58b5c324003c786ea67b27c71ab18044
# 2e6d305b011871ac5894272117c671c5  2e6d305b011871ac5894272117c671c5
# f66194ab6b6a720b595a015eb3939db1  f66194ab6b6a720b595a015eb3939db1
# 5217dc4a84dca358cd805bdab2c599cf  5217dc4a84dca358cd805bdab2c599cf
# 3c3138688d9db3deb581940adcf02d4d  3c3138688d9db3deb581940adcf02d4d
# 95fa7e1df5c5e3aea5929620c69a412f  95fa7e1df5c5e3aea5929620c69a412f
# ea24075cc4aed6b92bc511f7e7abec04  ea24075cc4aed6b92bc511f7e7abec04
# 41bf10d8ee2ab784f0f86c7ffeeb0e99  41bf10d8ee2ab784f0f86c7ffeeb0e99
# 918673823249b8a4d29b795a0bc7edfd  918673823249b8a4d29b795a0bc7edfd
# 0427e3863c8ad265500475e6bfb6a894  0427e3863c8ad265500475e6bfb6a894
# 9fded3746649c55506c6e4b35a780d45  9fded3746649c55506c6e4b35a780d45
# b618adbd1594259bcf1f37a9faa21cb6  b618adbd1594259bcf1f37a9faa21cb6
# be76dc8a7363499ff410aa4863e11489  be76dc8a7363499ff410aa4863e11489
# 47229b7dc33583ecee188bb177338e6b  47229b7dc33583ecee188bb177338e6b
# f3f53f8a82f194cedb0dcade4daf1f8a  f3f53f8a82f194cedb0dcade4daf1f8a
# d58331f774f4209d00011377308339f4  d58331f774f4209d00011377308339f4
# 33d03e1567b0bd82e4a96f6739d1c360  33d03e1567b0bd82e4a96f6739d1c360
# ace0ad8244f7cf188627cf2d46431f27  ace0ad8244f7cf188627cf2d46431f27
# 4b712e35b0bff2095b957288bf72f570  4b712e35b0bff2095b957288bf72f570
# 1991f22a1733ef3b6544dccf256c7463  1991f22a1733ef3b6544dccf256c7463
# bf27f08bf8dbe701e1b1100413b60ee0  bf27f08bf8dbe701e1b1100413b60ee0
# 9e94913e7d73b61cb6c039838f6b71bb  9e94913e7d73b61cb6c039838f6b71bb
# b10d1f6adaa55ab6a2779c2d5b95c505  b10d1f6adaa55ab6a2779c2d5b95c505
# 44a54cd3e74b0b3bc8c232eb9fa006b9  44a54cd3e74b0b3bc8c232eb9fa006b9
# 2aa51a93d229b08023ed296796a6727e  2aa51a93d229b08023ed296796a6727e
# da6c8c27b2d3859c2e10330db6bcc8ae  da6c8c27b2d3859c2e10330db6bcc8ae
#
#                                                          artist_id  \
# song_id
# 8c0af7b6cb812288cee966a8fa4bb0d4  2e14d32266ee6b4678595f8f50c369ac
# 7c681d27bf5d684f2c188611653ebf0f  2e14d32266ee6b4678595f8f50c369ac
# 43859bd7584a7aa43a28a7b05def5171  2e14d32266ee6b4678595f8f50c369ac
# dbf76bdb58c5249c5c94acf59a6ccb71  2e14d32266ee6b4678595f8f50c369ac
# 2af2818aad07f8725188b43a01fc9a6c  2e14d32266ee6b4678595f8f50c369ac
# 8c508dfa4dce1e62c8e932651f395df5  2e14d32266ee6b4678595f8f50c369ac
# 2d81384605726b0bb2cf63208ba5ddd7  2e14d32266ee6b4678595f8f50c369ac
# a1d22987106e889ec73143f56dca538b  2e14d32266ee6b4678595f8f50c369ac
# 8c8b30ec87c2e79245e48fd67e9eb199  2e14d32266ee6b4678595f8f50c369ac
# 3cb17112b2775dd44aec81ccec55d499  2e14d32266ee6b4678595f8f50c369ac
# 217396be947552523444055f0abab369  2e14d32266ee6b4678595f8f50c369ac
# 3de62f03b08964d37079230d6eed9b4f  2e14d32266ee6b4678595f8f50c369ac
# bec08290e3dbf0e059d8772bbb40d755  2e14d32266ee6b4678595f8f50c369ac
# 241b146e6b7c30e64d02699f6f2f9ebe  2e14d32266ee6b4678595f8f50c369ac
# cf3db2de287f966839bbdacc1f534298  2e14d32266ee6b4678595f8f50c369ac
# 9bc42c527ba9f7780de3e78876d13a16  2e14d32266ee6b4678595f8f50c369ac
# e4b2f80335d12fe1cb841f904b34d007  2e14d32266ee6b4678595f8f50c369ac
# 91551efd4a3a45e7488b30a50a662ed5  2e14d32266ee6b4678595f8f50c369ac
# 2a87b8eb06f111d7d289b79c3242b12c  2e14d32266ee6b4678595f8f50c369ac
# 60ce8fed0592407b882b3f171a2686d8  2e14d32266ee6b4678595f8f50c369ac
# c6491cda718afb65f7e5c08172315a6c  2e14d32266ee6b4678595f8f50c369ac
# 76a29e7c057b41f72f21cfc4d710d577  2e14d32266ee6b4678595f8f50c369ac
# 4d98fdab5930d2feb2084ebfdb01fc88  2e14d32266ee6b4678595f8f50c369ac
# b0074843cd57e8d7ea23dea663e72467  2e14d32266ee6b4678595f8f50c369ac
# f0ff0838ef045952d691673158c8eb44  2e14d32266ee6b4678595f8f50c369ac
# 0a6f8c28aa062602fbcee3cebd440968  2e14d32266ee6b4678595f8f50c369ac
# 3ccf6c61816550612e19b0b9b0470234  2e14d32266ee6b4678595f8f50c369ac
# 1c733936d1bb83aff7219e3b1a936a2f  2e14d32266ee6b4678595f8f50c369ac
# 40e0b72302cb8003c2b3479866b1703e  2e14d32266ee6b4678595f8f50c369ac
# ed7499bd2f9a6e35c20a364655c33d01  2e14d32266ee6b4678595f8f50c369ac
# ...                                                            ...
# 5421e28cc36c3ca5b9ccff8ba2c104a3  2e14d32266ee6b4678595f8f50c369ac
# 2e7d4a5b476cf385382776f30764415b  2e14d32266ee6b4678595f8f50c369ac
# 8102a76d4371894641cf62719147650e  2e14d32266ee6b4678595f8f50c369ac
# 7ff17510540bfe3f8ba07a6d71fb252d  2e14d32266ee6b4678595f8f50c369ac
# 58b5c324003c786ea67b27c71ab18044  2e14d32266ee6b4678595f8f50c369ac
# 2e6d305b011871ac5894272117c671c5  2e14d32266ee6b4678595f8f50c369ac
# f66194ab6b6a720b595a015eb3939db1  2e14d32266ee6b4678595f8f50c369ac
# 5217dc4a84dca358cd805bdab2c599cf  2e14d32266ee6b4678595f8f50c369ac
# 3c3138688d9db3deb581940adcf02d4d  2e14d32266ee6b4678595f8f50c369ac
# 95fa7e1df5c5e3aea5929620c69a412f  2e14d32266ee6b4678595f8f50c369ac
# ea24075cc4aed6b92bc511f7e7abec04  2e14d32266ee6b4678595f8f50c369ac
# 41bf10d8ee2ab784f0f86c7ffeeb0e99  2e14d32266ee6b4678595f8f50c369ac
# 918673823249b8a4d29b795a0bc7edfd  2e14d32266ee6b4678595f8f50c369ac
# 0427e3863c8ad265500475e6bfb6a894  2e14d32266ee6b4678595f8f50c369ac
# 9fded3746649c55506c6e4b35a780d45  2e14d32266ee6b4678595f8f50c369ac
# b618adbd1594259bcf1f37a9faa21cb6  2e14d32266ee6b4678595f8f50c369ac
# be76dc8a7363499ff410aa4863e11489  2e14d32266ee6b4678595f8f50c369ac
# 47229b7dc33583ecee188bb177338e6b  2e14d32266ee6b4678595f8f50c369ac
# f3f53f8a82f194cedb0dcade4daf1f8a  2e14d32266ee6b4678595f8f50c369ac
# d58331f774f4209d00011377308339f4  2e14d32266ee6b4678595f8f50c369ac
# 33d03e1567b0bd82e4a96f6739d1c360  2e14d32266ee6b4678595f8f50c369ac
# ace0ad8244f7cf188627cf2d46431f27  2e14d32266ee6b4678595f8f50c369ac
# 4b712e35b0bff2095b957288bf72f570  2e14d32266ee6b4678595f8f50c369ac
# 1991f22a1733ef3b6544dccf256c7463  2e14d32266ee6b4678595f8f50c369ac
# bf27f08bf8dbe701e1b1100413b60ee0  2e14d32266ee6b4678595f8f50c369ac
# 9e94913e7d73b61cb6c039838f6b71bb  2e14d32266ee6b4678595f8f50c369ac
# b10d1f6adaa55ab6a2779c2d5b95c505  2e14d32266ee6b4678595f8f50c369ac
# 44a54cd3e74b0b3bc8c232eb9fa006b9  2e14d32266ee6b4678595f8f50c369ac
# 2aa51a93d229b08023ed296796a6727e  2e14d32266ee6b4678595f8f50c369ac
# da6c8c27b2d3859c2e10330db6bcc8ae  2e14d32266ee6b4678595f8f50c369ac
#
#                                   publish_time  song_init_plays  Language  \
# song_id
# 8c0af7b6cb812288cee966a8fa4bb0d4      19961220             7244        11
# 7c681d27bf5d684f2c188611653ebf0f      19961220          2420338        11
# 43859bd7584a7aa43a28a7b05def5171      19951222            10055        11
# dbf76bdb58c5249c5c94acf59a6ccb71      19951222             4325        11
# 2af2818aad07f8725188b43a01fc9a6c      19951222             3807        11
# 8c508dfa4dce1e62c8e932651f395df5      19950509             9138        11
# 2d81384605726b0bb2cf63208ba5ddd7      19950509             2888        11
# a1d22987106e889ec73143f56dca538b      19940615             4699        11
# 8c8b30ec87c2e79245e48fd67e9eb199      19891110             1482         1
# 3cb17112b2775dd44aec81ccec55d499      19891110             2551         1
# 217396be947552523444055f0abab369      19940615             3211        11
# 3de62f03b08964d37079230d6eed9b4f      19930401            14805         1
# bec08290e3dbf0e059d8772bbb40d755      19930401             4090         1
# 241b146e6b7c30e64d02699f6f2f9ebe      19930401          1101665         1
# cf3db2de287f966839bbdacc1f534298      19940601             3914         1
# 9bc42c527ba9f7780de3e78876d13a16      19940601            27056         1
# e4b2f80335d12fe1cb841f904b34d007      20060331             5013         1
# 91551efd4a3a45e7488b30a50a662ed5      20060331            11367         1
# 2a87b8eb06f111d7d289b79c3242b12c      19930401             4432         1
# 60ce8fed0592407b882b3f171a2686d8      19930401             4792         1
# c6491cda718afb65f7e5c08172315a6c      19930401             6983         1
# 76a29e7c057b41f72f21cfc4d710d577      19940615             4178        11
# 4d98fdab5930d2feb2084ebfdb01fc88      19940615            15317        11
# b0074843cd57e8d7ea23dea663e72467      19950509             3818        11
# f0ff0838ef045952d691673158c8eb44      19950509             5123        11
# 0a6f8c28aa062602fbcee3cebd440968      19951222             4877        11
# 3ccf6c61816550612e19b0b9b0470234      19961220             5447        11
# 1c733936d1bb83aff7219e3b1a936a2f      19961220            22062        11
# 40e0b72302cb8003c2b3479866b1703e      19961220            18047        11
# ed7499bd2f9a6e35c20a364655c33d01      19991129             2591         1
# ...                                        ...              ...       ...
# 5421e28cc36c3ca5b9ccff8ba2c104a3      20131206            22632         1
# 2e7d4a5b476cf385382776f30764415b      19960202             3241         1
# 8102a76d4371894641cf62719147650e      20131206            31788         1
# 7ff17510540bfe3f8ba07a6d71fb252d      20131206            37140         1
# 58b5c324003c786ea67b27c71ab18044      19910211              774         4
# 2e6d305b011871ac5894272117c671c5      19891110             5113         1
# f66194ab6b6a720b595a015eb3939db1      19970416             8487         1
# 5217dc4a84dca358cd805bdab2c599cf      20030901             6858         1
# 3c3138688d9db3deb581940adcf02d4d      19991129            11304         1
# 95fa7e1df5c5e3aea5929620c69a412f      19960601             3511         1
# ea24075cc4aed6b92bc511f7e7abec04      19960601             4295         1
# 41bf10d8ee2ab784f0f86c7ffeeb0e99      20011016            12959         1
# 918673823249b8a4d29b795a0bc7edfd      20011016             5792         1
# 0427e3863c8ad265500475e6bfb6a894      19880829            14557         1
# 9fded3746649c55506c6e4b35a780d45      19880829             1778         1
# b618adbd1594259bcf1f37a9faa21cb6      19950101             7727         1
# be76dc8a7363499ff410aa4863e11489      19950101            10446         1
# 47229b7dc33583ecee188bb177338e6b      19970416             5140         1
# f3f53f8a82f194cedb0dcade4daf1f8a      19970416             3266         1
# d58331f774f4209d00011377308339f4      19960202            12834         1
# 33d03e1567b0bd82e4a96f6739d1c360      19960202             6875         1
# ace0ad8244f7cf188627cf2d46431f27      19960202             1594         1
# 4b712e35b0bff2095b957288bf72f570      19950701             3999         1
# 1991f22a1733ef3b6544dccf256c7463      19950701            51777         1
# bf27f08bf8dbe701e1b1100413b60ee0      19991129            14392         1
# 9e94913e7d73b61cb6c039838f6b71bb      20131206            61848         1
# b10d1f6adaa55ab6a2779c2d5b95c505      19940615             4603        11
# 44a54cd3e74b0b3bc8c232eb9fa006b9      20030901             8643         1
# 2aa51a93d229b08023ed296796a6727e      19890127             2442         1
# da6c8c27b2d3859c2e10330db6bcc8ae      19991129             4089         1
#
#                                   Gender  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# song_id
# 8c0af7b6cb812288cee966a8fa4bb0d4       1         NaN         NaN         NaN
# 7c681d27bf5d684f2c188611653ebf0f       1         NaN         NaN         NaN
# 43859bd7584a7aa43a28a7b05def5171       1         NaN         NaN         NaN
# dbf76bdb58c5249c5c94acf59a6ccb71       1         NaN         NaN         NaN
# 2af2818aad07f8725188b43a01fc9a6c       1         NaN         NaN         NaN
# 8c508dfa4dce1e62c8e932651f395df5       1         NaN         NaN         NaN
# 2d81384605726b0bb2cf63208ba5ddd7       1         NaN         NaN         NaN
# a1d22987106e889ec73143f56dca538b       1         NaN         NaN         NaN
# 8c8b30ec87c2e79245e48fd67e9eb199       1         NaN         NaN         NaN
# 3cb17112b2775dd44aec81ccec55d499       1         NaN         NaN         NaN
# 217396be947552523444055f0abab369       1         NaN         NaN         NaN
# 3de62f03b08964d37079230d6eed9b4f       1         NaN         NaN         NaN
# bec08290e3dbf0e059d8772bbb40d755       1         NaN         NaN         NaN
# 241b146e6b7c30e64d02699f6f2f9ebe       1         NaN         NaN         NaN
# cf3db2de287f966839bbdacc1f534298       1         NaN         NaN         NaN
# 9bc42c527ba9f7780de3e78876d13a16       1         NaN         NaN         NaN
# e4b2f80335d12fe1cb841f904b34d007       1         NaN         NaN         NaN
# 91551efd4a3a45e7488b30a50a662ed5       1         NaN         NaN         NaN
# 2a87b8eb06f111d7d289b79c3242b12c       1         NaN         NaN         NaN
# 60ce8fed0592407b882b3f171a2686d8       1         NaN         NaN         NaN
# c6491cda718afb65f7e5c08172315a6c       1         NaN         NaN         NaN
# 76a29e7c057b41f72f21cfc4d710d577       1         NaN         NaN         NaN
# 4d98fdab5930d2feb2084ebfdb01fc88       1         NaN         NaN         NaN
# b0074843cd57e8d7ea23dea663e72467       1         NaN         NaN         NaN
# f0ff0838ef045952d691673158c8eb44       1         NaN         NaN         NaN
# 0a6f8c28aa062602fbcee3cebd440968       1         NaN         NaN         NaN
# 3ccf6c61816550612e19b0b9b0470234       1         NaN         NaN         NaN
# 1c733936d1bb83aff7219e3b1a936a2f       1         NaN         NaN         NaN
# 40e0b72302cb8003c2b3479866b1703e       1         NaN         NaN         NaN
# ed7499bd2f9a6e35c20a364655c33d01       1         NaN         NaN         NaN
# ...                                  ...         ...         ...         ...
# 5421e28cc36c3ca5b9ccff8ba2c104a3       1         NaN         NaN         NaN
# 2e7d4a5b476cf385382776f30764415b       1         NaN         NaN         NaN
# 8102a76d4371894641cf62719147650e       1         NaN         NaN         NaN
# 7ff17510540bfe3f8ba07a6d71fb252d       1         NaN         NaN         NaN
# 58b5c324003c786ea67b27c71ab18044       1         NaN         NaN         NaN
# 2e6d305b011871ac5894272117c671c5       1         NaN         NaN         NaN
# f66194ab6b6a720b595a015eb3939db1       1         NaN         NaN         NaN
# 5217dc4a84dca358cd805bdab2c599cf       1         NaN         NaN         NaN
# 3c3138688d9db3deb581940adcf02d4d       1         NaN         NaN         NaN
# 95fa7e1df5c5e3aea5929620c69a412f       1         NaN         NaN         NaN
# ea24075cc4aed6b92bc511f7e7abec04       1         NaN         NaN         NaN
# 41bf10d8ee2ab784f0f86c7ffeeb0e99       1         NaN         NaN         NaN
# 918673823249b8a4d29b795a0bc7edfd       1         NaN         NaN         NaN
# 0427e3863c8ad265500475e6bfb6a894       1         NaN         NaN         NaN
# 9fded3746649c55506c6e4b35a780d45       1         NaN         NaN         NaN
# b618adbd1594259bcf1f37a9faa21cb6       1         NaN         NaN         NaN
# be76dc8a7363499ff410aa4863e11489       1         NaN         NaN         NaN
# 47229b7dc33583ecee188bb177338e6b       1         NaN         NaN         NaN
# f3f53f8a82f194cedb0dcade4daf1f8a       1         NaN         NaN         NaN
# d58331f774f4209d00011377308339f4       1         NaN         NaN         NaN
# 33d03e1567b0bd82e4a96f6739d1c360       1         NaN         NaN         NaN
# ace0ad8244f7cf188627cf2d46431f27       1         NaN         NaN         NaN
# 4b712e35b0bff2095b957288bf72f570       1         NaN         NaN         NaN
# 1991f22a1733ef3b6544dccf256c7463       1         NaN         NaN         NaN
# bf27f08bf8dbe701e1b1100413b60ee0       1         NaN         NaN         NaN
# 9e94913e7d73b61cb6c039838f6b71bb       1         NaN         NaN         NaN
# b10d1f6adaa55ab6a2779c2d5b95c505       1         NaN         NaN         NaN
# 44a54cd3e74b0b3bc8c232eb9fa006b9       1         NaN         NaN         NaN
# 2aa51a93d229b08023ed296796a6727e       1         NaN         NaN         NaN
# da6c8c27b2d3859c2e10330db6bcc8ae       1         NaN         NaN         NaN
#
#                                   Unnamed: 9  Unnamed: 10  Unnamed: 11
# song_id
# 8c0af7b6cb812288cee966a8fa4bb0d4         NaN          NaN          NaN
# 7c681d27bf5d684f2c188611653ebf0f         NaN          NaN          NaN
# 43859bd7584a7aa43a28a7b05def5171         NaN          NaN          NaN
# dbf76bdb58c5249c5c94acf59a6ccb71         NaN          NaN          NaN
# 2af2818aad07f8725188b43a01fc9a6c         NaN          NaN          NaN
# 8c508dfa4dce1e62c8e932651f395df5         NaN          NaN          NaN
# 2d81384605726b0bb2cf63208ba5ddd7         NaN          NaN          NaN
# a1d22987106e889ec73143f56dca538b         NaN          NaN          NaN
# 8c8b30ec87c2e79245e48fd67e9eb199         NaN          NaN          NaN
# 3cb17112b2775dd44aec81ccec55d499         NaN          NaN          NaN
# 217396be947552523444055f0abab369         NaN          NaN          NaN
# 3de62f03b08964d37079230d6eed9b4f         NaN          NaN          NaN
# bec08290e3dbf0e059d8772bbb40d755         NaN          NaN          NaN
# 241b146e6b7c30e64d02699f6f2f9ebe         NaN          NaN          NaN
# cf3db2de287f966839bbdacc1f534298         NaN          NaN          NaN
# 9bc42c527ba9f7780de3e78876d13a16         NaN          NaN          NaN
# e4b2f80335d12fe1cb841f904b34d007         NaN          NaN          NaN
# 91551efd4a3a45e7488b30a50a662ed5         NaN          NaN          NaN
# 2a87b8eb06f111d7d289b79c3242b12c         NaN          NaN          NaN
# 60ce8fed0592407b882b3f171a2686d8         NaN          NaN          NaN
# c6491cda718afb65f7e5c08172315a6c         NaN          NaN          NaN
# 76a29e7c057b41f72f21cfc4d710d577         NaN          NaN          NaN
# 4d98fdab5930d2feb2084ebfdb01fc88         NaN          NaN          NaN
# b0074843cd57e8d7ea23dea663e72467         NaN          NaN          NaN
# f0ff0838ef045952d691673158c8eb44         NaN          NaN          NaN
# 0a6f8c28aa062602fbcee3cebd440968         NaN          NaN          NaN
# 3ccf6c61816550612e19b0b9b0470234         NaN          NaN          NaN
# 1c733936d1bb83aff7219e3b1a936a2f         NaN          NaN          NaN
# 40e0b72302cb8003c2b3479866b1703e         NaN          NaN          NaN
# ed7499bd2f9a6e35c20a364655c33d01         NaN          NaN          NaN
# ...                                      ...          ...          ...
# 5421e28cc36c3ca5b9ccff8ba2c104a3         NaN          NaN          NaN
# 2e7d4a5b476cf385382776f30764415b         NaN          NaN          NaN
# 8102a76d4371894641cf62719147650e         NaN          NaN          NaN
# 7ff17510540bfe3f8ba07a6d71fb252d         NaN          NaN          NaN
# 58b5c324003c786ea67b27c71ab18044         NaN          NaN          NaN
# 2e6d305b011871ac5894272117c671c5         NaN          NaN          NaN
# f66194ab6b6a720b595a015eb3939db1         NaN          NaN          NaN
# 5217dc4a84dca358cd805bdab2c599cf         NaN          NaN          NaN
# 3c3138688d9db3deb581940adcf02d4d         NaN          NaN          NaN
# 95fa7e1df5c5e3aea5929620c69a412f         NaN          NaN          NaN
# ea24075cc4aed6b92bc511f7e7abec04         NaN          NaN          NaN
# 41bf10d8ee2ab784f0f86c7ffeeb0e99         NaN          NaN          NaN
# 918673823249b8a4d29b795a0bc7edfd         NaN          NaN          NaN
# 0427e3863c8ad265500475e6bfb6a894         NaN          NaN          NaN
# 9fded3746649c55506c6e4b35a780d45         NaN          NaN          NaN
# b618adbd1594259bcf1f37a9faa21cb6         NaN          NaN          NaN
# be76dc8a7363499ff410aa4863e11489         NaN          NaN          NaN
# 47229b7dc33583ecee188bb177338e6b         NaN          NaN          NaN
# f3f53f8a82f194cedb0dcade4daf1f8a         NaN          NaN          NaN
# d58331f774f4209d00011377308339f4         NaN          NaN          NaN
# 33d03e1567b0bd82e4a96f6739d1c360         NaN          NaN          NaN
# ace0ad8244f7cf188627cf2d46431f27         NaN          NaN          NaN
# 4b712e35b0bff2095b957288bf72f570         NaN          NaN          NaN
# 1991f22a1733ef3b6544dccf256c7463         NaN          NaN          NaN
# bf27f08bf8dbe701e1b1100413b60ee0         NaN          NaN          NaN
# 9e94913e7d73b61cb6c039838f6b71bb         NaN          NaN          NaN
# b10d1f6adaa55ab6a2779c2d5b95c505         NaN          NaN          NaN
# 44a54cd3e74b0b3bc8c232eb9fa006b9         NaN          NaN          NaN
# 2aa51a93d229b08023ed296796a6727e         NaN          NaN          NaN
# da6c8c27b2d3859c2e10330db6bcc8ae         NaN          NaN          NaN
#
# [621 rows x 12 columns]
